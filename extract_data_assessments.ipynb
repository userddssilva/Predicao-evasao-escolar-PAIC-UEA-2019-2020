# %% [markdown]
# ## Estrutura de armazenamento dos dados

# %% [markdown]
# ```
#     semester_id
#              |--- class_id
#              |        |--- assessment_id
#              |        |      |--- {feature1 : feature_value}
#              |        |      |--- {feature2 : feature_value}
#              |        |      |--- .......
#              |        |      |--- {featureN : feature_value}
# ```

# %% [markdown]
# ## Extraindo os dados dos arquivos

# %% [markdown]
# ### Importando bibliotecas

# %%
import tarfile
import os
import re
import pymysql

from pprint import pprint

# %% [markdown]
# ### Coletando os semestres

# %%
PATH = '../dataset/workbench'
dataset = {}
for semester_id in os.listdir(PATH):
    if re.search(r'\d{4}-\d', semester_id):
        dataset[semester_id] = {}

pprint(dataset)
# Out:
# {'2016-1': {},
#  '2016-2': {},
#  '2017-1': {},
#  '2017-2': {},
#  '2018-1': {},
#  '2018-2': {},
#  '2019-1': {}}

# %% [markdown]
# ### Coletando as turmas

# %%
PATH = '../dataset/workbench/{semester_id}'

for semester_id in dataset.keys():
    path = PATH.replace('{semester_id}', semester_id)
    for class_id in os.listdir(path):
        if re.match(r'\d+', class_id):
            dataset[semester_id][class_id] = {}

pprint(dataset)
# Out:
# {'2016-1': {'102': {},
#             '103': {},
#             '105': {},
#             '106': {},
#             '107': {},
#             '108': {},
#             '109': {},
#             '110': {},
#             '111': {}},
#  '2016-2': {'122': {}, '124': {}, '125': {}, '127': {}, '128': {}},
#  '2017-1': {'135': {},
#             '136': {},
#             '137': {},
#             '138': {},
#             '139': {},
#             '140': {},
#             '141': {},
#             '142': {},
#             '143': {},
#             '144': {}},
#  '2017-2': {'160': {}, '162': {}, '163': {}, '164': {}, '165': {}},
#  '2018-1': {'180': {},
#             '181': {},
#             '183': {},
#             '185': {},
#             '186': {},
#             '187': {},
#             '188': {},
#             '189': {},
#             '190': {}},
#  '2018-2': {'204': {}, '205': {}, '206': {}, '207': {}, '208': {}},
#  '2019-1': {'220': {},
#             '221': {},
#             '222': {},
#             '223': {},
#             '224': {},
#             '225': {},
#             '226': {},
#             '230': {},
#             '231': {}}}

# %% [markdown]
# ### Coletando os id's das avaliações

# %%
PATH = '../dataset/workbench/{semester_id}/{class_id}/assessments/'

for semester_id in dataset.keys():
    # print(semester_id)
    for class_id in dataset[semester_id].keys():
        path = PATH.replace('{semester_id}', semester_id)
        path = path.replace('{class_id}', class_id)
        # print(' ', class_id)
        for assessment_id in os.listdir(path):
            #print('  ', assessment_id)
            assessment_id = re.sub(r'.data','', assessment_id)
            dataset[semester_id][class_id][assessment_id] = {}
        # print(f' class_id={class_id}, path={path}')

pprint(dataset)
# Out:
# {'2016-1': {'102': {'106': {},
#                     '126': {},
#                     '136': {},
#                     '149': {},
#                     '158': {},
#                     '173': {},
#                     '18': {},
#                     '184': {},
#                     '199': {},
#                     '208': {},
#                     '217': {},
#                     '44': {},
#                     '59': {},
#                     '75': {},
#                     '97': {}},
#             '103': {'103': {},
#                     '122': {},
#                     '131': {},
#                     '148': {},
#                     '163': {},
#                     '174': {},
#                     '180': {},
#                     '197': {},
#                     '205': {},
#                     '216': {},
#                     '27': {},
#                     '42': {},
#                     '48': {},
#                     '74': {},
#                     '94': {}},
#             '105': {'112': {},
#                     '120': {},
#                     '128': {},
#                     '140': {},
#                     '144': {},
#                     '165': {},
#                     '177': {},
#                     '191': {},
#                     '192': {},
#                     '212': {},
#                     '213': {},
#                     '224': {},
#                     '36': {},
#                     '54': {},
#                     '83': {},
#                     '98': {}},
#             '106': {'111': {},
#                     '129': {},
#                     '135': {},
#                     '152': {},
#                     '162': {},
#                     '175': {},
#                     '189': {},
#                     '201': {},
#                     '210': {},
#                     '220': {},
#                     '51': {},
#                     '53': {},
#                     '63': {},
#                     '71': {},
#                     '93': {}},
#             '107': {'107': {},
#                     '127': {},
#                     '137': {},
#                     '150': {},
#                     '160': {},
#                     '176': {},
#                     '185': {},
#                     '200': {},
#                     '211': {},
#                     '219': {},
#                     '46': {},
#                     '47': {},
#                     '64': {},
#                     '81': {},
#                     '96': {}},
#             '108': {'109': {},
#                     '130': {},
#                     '141': {},
#                     '151': {},
#                     '161': {},
#                     '169': {},
#                     '187': {},
#                     '193': {},
#                     '209': {},
#                     '218': {},
#                     '28': {},
#                     '49': {},
#                     '62': {},
#                     '76': {},
#                     '99': {}},
#             '109': {'104': {},
#                     '121': {},
#                     '133': {},
#                     '145': {},
#                     '155': {},
#                     '170': {},
#                     '181': {},
#                     '195': {},
#                     '206': {},
#                     '222': {},
#                     '23': {},
#                     '39': {},
#                     '41': {},
#                     '72': {},
#                     '92': {}},
#             '110': {'105': {},
#                     '119': {},
#                     '134': {},
#                     '147': {},
#                     '156': {},
#                     '171': {},
#                     '183': {},
#                     '196': {},
#                     '207': {},
#                     '22': {},
#                     '223': {},
#                     '38': {},
#                     '40': {},
#                     '73': {},
#                     '95': {}},
#             '111': {'102': {},
#                     '117': {},
#                     '132': {},
#                     '154': {},
#                     '168': {},
#                     '179': {},
#                     '190': {},
#                     '194': {},
#                     '21': {},
#                     '214': {},
#                     '32': {},
#                     '35': {},
#                     '69': {},
#                     '88': {},
#                     '89': {}}},
#  '2016-2': {'122': {'234': {},
#                     '248': {},
#                     '269': {},
#                     '275': {},
#                     '281': {},
#                     '293': {},
#                     '307': {},
#                     '310': {},
#                     '314': {},
#                     '317': {},
#                     '335': {},
#                     '344': {},
#                     '361': {},
#                     '365': {},
#                     '370': {},
#                     '376': {},
#                     '382': {}},
#             '124': {'237': {},
#                     '253': {},
#                     '270': {},
#                     '276': {},
#                     '289': {},
#                     '292': {},
#                     '312': {},
#                     '326': {},
#                     '327': {},
#                     '328': {},
#                     '336': {},
#                     '347': {},
#                     '356': {},
#                     '369': {},
#                     '375': {},
#                     '383': {},
#                     '387': {}},
#             '125': {'232': {},
#                     '241': {},
#                     '271': {},
#                     '282': {},
#                     '291': {},
#                     '300': {},
#                     '313': {},
#                     '320': {},
#                     '321': {},
#                     '333': {},
#                     '342': {},
#                     '349': {},
#                     '359': {},
#                     '366': {},
#                     '371': {},
#                     '379': {},
#                     '388': {}},
#             '127': {'243': {},
#                     '265': {},
#                     '280': {},
#                     '286': {},
#                     '294': {},
#                     '301': {},
#                     '311': {},
#                     '318': {},
#                     '319': {},
#                     '334': {},
#                     '343': {},
#                     '348': {},
#                     '357': {},
#                     '367': {},
#                     '373': {},
#                     '380': {},
#                     '385': {}},
#             '128': {'251': {},
#                     '252': {},
#                     '277': {},
#                     '283': {},
#                     '295': {},
#                     '302': {},
#                     '315': {},
#                     '322': {},
#                     '323': {},
#                     '325': {},
#                     '340': {},
#                     '350': {},
#                     '360': {},
#                     '368': {},
#                     '372': {},
#                     '378': {},
#                     '386': {}}},
#  '2017-1': {'135': {'409': {},
#                     '429': {},
#                     '454': {},
#                     '468': {},
#                     '477': {},
#                     '495': {},
#                     '509': {},
#                     '518': {},
#                     '546': {},
#                     '559': {},
#                     '584': {},
#                     '608': {},
#                     '611': {},
#                     '632': {},
#                     '649': {},
#                     '663': {},
#                     '682': {},
#                     '683': {},
#                     '711': {},
#                     '729': {},
#                     '744': {},
#                     '746': {},
#                     '769': {}},
#             '136': {'407': {},
#                     '455': {},
#                     '456': {},
#                     '474': {},
#                     '493': {},
#                     '494': {},
#                     '523': {},
#                     '533': {},
#                     '534': {},
#                     '569': {},
#                     '587': {},
#                     '589': {},
#                     '621': {},
#                     '630': {},
#                     '659': {},
#                     '671': {},
#                     '693': {},
#                     '694': {},
#                     '721': {},
#                     '737': {},
#                     '748': {},
#                     '750': {},
#                     '776': {}},
#             '137': {'411': {},
#                     '433': {},
#                     '438': {},
#                     '476': {},
#                     '481': {},
#                     '483': {},
#                     '522': {},
#                     '531': {},
#                     '532': {},
#                     '562': {},
#                     '563': {},
#                     '585': {},
#                     '620': {},
#                     '634': {},
#                     '668': {},
#                     '673': {},
#                     '681': {},
#                     '688': {},
#                     '689': {},
#                     '720': {},
#                     '725': {},
#                     '747': {},
#                     '749': {},
#                     '777': {}},
#             '138': {'410': {},
#                     '437': {},
#                     '466': {},
#                     '480': {},
#                     '501': {},
#                     '502': {},
#                     '529': {},
#                     '547': {},
#                     '548': {},
#                     '574': {},
#                     '588': {},
#                     '590': {},
#                     '613': {},
#                     '638': {},
#                     '666': {},
#                     '670': {},
#                     '690': {},
#                     '691': {},
#                     '717': {},
#                     '730': {},
#                     '766': {},
#                     '781': {},
#                     '782': {}},
#             '139': {'413': {},
#                     '436': {},
#                     '457': {},
#                     '475': {},
#                     '503': {},
#                     '504': {},
#                     '525': {},
#                     '552': {},
#                     '553': {},
#                     '577': {},
#                     '593': {},
#                     '594': {},
#                     '623': {},
#                     '635': {},
#                     '653': {},
#                     '669': {},
#                     '695': {},
#                     '696': {},
#                     '715': {},
#                     '734': {},
#                     '752': {},
#                     '757': {}},
#             '140': {'408': {},
#                     '439': {},
#                     '441': {},
#                     '487': {},
#                     '497': {},
#                     '505': {},
#                     '539': {},
#                     '542': {},
#                     '543': {},
#                     '576': {},
#                     '605': {},
#                     '606': {},
#                     '627': {},
#                     '640': {},
#                     '658': {},
#                     '675': {},
#                     '684': {},
#                     '685': {},
#                     '722': {},
#                     '726': {},
#                     '751': {},
#                     '772': {}},
#             '141': {'399': {},
#                     '442': {},
#                     '450': {},
#                     '478': {},
#                     '485': {},
#                     '486': {},
#                     '540': {},
#                     '556': {},
#                     '557': {},
#                     '579': {},
#                     '600': {},
#                     '601': {},
#                     '622': {},
#                     '642': {},
#                     '657': {},
#                     '674': {},
#                     '701': {},
#                     '702': {},
#                     '719': {},
#                     '733': {},
#                     '759': {},
#                     '761': {}},
#             '142': {'397': {},
#                     '446': {},
#                     '447': {},
#                     '488': {},
#                     '506': {},
#                     '507': {},
#                     '541': {},
#                     '554': {},
#                     '555': {},
#                     '580': {},
#                     '597': {},
#                     '598': {},
#                     '626': {},
#                     '641': {},
#                     '656': {},
#                     '672': {},
#                     '699': {},
#                     '700': {},
#                     '714': {},
#                     '732': {},
#                     '754': {},
#                     '768': {},
#                     '778': {}},
#             '143': {'400': {},
#                     '440': {},
#                     '452': {},
#                     '473': {},
#                     '491': {},
#                     '492': {},
#                     '526': {},
#                     '535': {},
#                     '545': {},
#                     '565': {},
#                     '591': {},
#                     '592': {},
#                     '614': {},
#                     '636': {},
#                     '654': {},
#                     '667': {},
#                     '686': {},
#                     '687': {},
#                     '712': {},
#                     '736': {},
#                     '745': {},
#                     '755': {}},
#             '144': {'391': {},
#                     '445': {},
#                     '449': {},
#                     '465': {},
#                     '484': {},
#                     '490': {},
#                     '515': {},
#                     '536': {},
#                     '537': {},
#                     '560': {},
#                     '595': {},
#                     '596': {},
#                     '612': {},
#                     '639': {},
#                     '652': {},
#                     '664': {},
#                     '697': {},
#                     '698': {},
#                     '710': {},
#                     '731': {},
#                     '738': {},
#                     '756': {}}},
#  '2017-2': {'160': {'1003': {},
#                     '800': {},
#                     '819': {},
#                     '830': {},
#                     '831': {},
#                     '847': {},
#                     '858': {},
#                     '863': {},
#                     '877': {},
#                     '882': {},
#                     '886': {},
#                     '899': {},
#                     '900': {},
#                     '923': {},
#                     '932': {},
#                     '933': {},
#                     '962': {},
#                     '971': {},
#                     '972': {},
#                     '980': {},
#                     '981': {},
#                     '982': {},
#                     '991': {},
#                     '995': {}},
#             '162': {'1001': {},
#                     '1005': {},
#                     '1006': {},
#                     '789': {},
#                     '812': {},
#                     '834': {},
#                     '835': {},
#                     '842': {},
#                     '851': {},
#                     '859': {},
#                     '874': {},
#                     '881': {},
#                     '883': {},
#                     '892': {},
#                     '905': {},
#                     '922': {},
#                     '928': {},
#                     '929': {},
#                     '941': {},
#                     '959': {},
#                     '960': {},
#                     '973': {},
#                     '977': {},
#                     '978': {},
#                     '993': {}},
#             '163': {'1000': {},
#                     '790': {},
#                     '813': {},
#                     '832': {},
#                     '833': {},
#                     '841': {},
#                     '845': {},
#                     '861': {},
#                     '869': {},
#                     '880': {},
#                     '884': {},
#                     '893': {},
#                     '894': {},
#                     '921': {},
#                     '926': {},
#                     '927': {},
#                     '937': {},
#                     '957': {},
#                     '958': {},
#                     '970': {},
#                     '975': {},
#                     '976': {},
#                     '987': {}},
#             '164': {'1002': {},
#                     '1004': {},
#                     '795': {},
#                     '818': {},
#                     '838': {},
#                     '848': {},
#                     '849': {},
#                     '862': {},
#                     '878': {},
#                     '888': {},
#                     '901': {},
#                     '902': {},
#                     '925': {},
#                     '931': {},
#                     '944': {},
#                     '966': {},
#                     '974': {},
#                     '983': {},
#                     '994': {}},
#             '165': {'798': {},
#                     '816': {},
#                     '836': {},
#                     '844': {},
#                     '853': {},
#                     '854': {},
#                     '866': {},
#                     '875': {},
#                     '887': {},
#                     '897': {},
#                     '934': {},
#                     '942': {}}},
#  '2018-1': {'180': {'1018': {},
#                     '1037': {},
#                     '1048': {},
#                     '1061': {},
#                     '1086': {},
#                     '1092': {},
#                     '1100': {},
#                     '1135': {},
#                     '1136': {},
#                     '1150': {},
#                     '1169': {},
#                     '1186': {},
#                     '1188': {},
#                     '1211': {},
#                     '1216': {},
#                     '1234': {},
#                     '1251': {},
#                     '1252': {},
#                     '1270': {},
#                     '1289': {},
#                     '1290': {},
#                     '1305': {},
#                     '1312': {}},
#             '181': {'1017': {},
#                     '1031': {},
#                     '1043': {},
#                     '1056': {},
#                     '1083': {},
#                     '1085': {},
#                     '1095': {},
#                     '1118': {},
#                     '1123': {},
#                     '1145': {},
#                     '1162': {},
#                     '1172': {},
#                     '1183': {},
#                     '1198': {},
#                     '1212': {},
#                     '1225': {},
#                     '1244': {},
#                     '1245': {},
#                     '1258': {},
#                     '1265': {},
#                     '1292': {},
#                     '1301': {},
#                     '1303': {}},
#             '183': {'1015': {},
#                     '1042': {},
#                     '1044': {},
#                     '1066': {},
#                     '1074': {},
#                     '1075': {},
#                     '1109': {},
#                     '1127': {},
#                     '1128': {},
#                     '1151': {},
#                     '1156': {},
#                     '1174': {},
#                     '1181': {},
#                     '1195': {},
#                     '1213': {},
#                     '1223': {},
#                     '1236': {},
#                     '1237': {},
#                     '1261': {},
#                     '1279': {},
#                     '1296': {},
#                     '1298': {}},
#             '185': {'1021': {},
#                     '1039': {},
#                     '1069': {},
#                     '1070': {},
#                     '1079': {},
#                     '1080': {},
#                     '1111': {},
#                     '1131': {},
#                     '1137': {},
#                     '1154': {},
#                     '1165': {},
#                     '1173': {},
#                     '1193': {},
#                     '1201': {},
#                     '1214': {},
#                     '1222': {},
#                     '1238': {},
#                     '1239': {},
#                     '1260': {},
#                     '1280': {},
#                     '1295': {},
#                     '1310': {}},
#             '186': {'1014': {},
#                     '1035': {},
#                     '1045': {},
#                     '1058': {},
#                     '1072': {},
#                     '1073': {},
#                     '1097': {},
#                     '1120': {},
#                     '1132': {},
#                     '1147': {},
#                     '1158': {},
#                     '1175': {},
#                     '1187': {},
#                     '1199': {},
#                     '1215': {},
#                     '1232': {},
#                     '1246': {},
#                     '1250': {},
#                     '1266': {},
#                     '1286': {},
#                     '1293': {},
#                     '1313': {}},
#             '187': {'1019': {},
#                     '1038': {},
#                     '1047': {},
#                     '1060': {},
#                     '1087': {},
#                     '1088': {},
#                     '1099': {},
#                     '1133': {},
#                     '1134': {},
#                     '1149': {},
#                     '1159': {},
#                     '1176': {},
#                     '1189': {},
#                     '1208': {},
#                     '1209': {},
#                     '1235': {},
#                     '1253': {},
#                     '1254': {},
#                     '1269': {},
#                     '1283': {},
#                     '1291': {},
#                     '1304': {},
#                     '1314': {}},
#             '188': {'1016': {},
#                     '1034': {},
#                     '1054': {},
#                     '1062': {},
#                     '1078': {},
#                     '1098': {},
#                     '1121': {},
#                     '1125': {},
#                     '1126': {},
#                     '1148': {},
#                     '1161': {},
#                     '1190': {},
#                     '1200': {},
#                     '1205': {},
#                     '1207': {},
#                     '1233': {},
#                     '1248': {},
#                     '1262': {},
#                     '1276': {},
#                     '1285': {},
#                     '1306': {},
#                     '1315': {},
#                     '1317': {}},
#             '189': {'1012': {},
#                     '1029': {},
#                     '1051': {},
#                     '1052': {},
#                     '1084': {},
#                     '1089': {},
#                     '1106': {},
#                     '1129': {},
#                     '1130': {},
#                     '1152': {},
#                     '1155': {},
#                     '1170': {},
#                     '1182': {},
#                     '1194': {},
#                     '1204': {},
#                     '1220': {},
#                     '1228': {},
#                     '1230': {},
#                     '1255': {},
#                     '1273': {},
#                     '1294': {},
#                     '1302': {},
#                     '1311': {}},
#             '190': {'1013': {},
#                     '1030': {},
#                     '1041': {},
#                     '1053': {},
#                     '1076': {},
#                     '1077': {},
#                     '1096': {},
#                     '1119': {},
#                     '1124': {},
#                     '1146': {},
#                     '1157': {},
#                     '1171': {},
#                     '1184': {},
#                     '1197': {},
#                     '1203': {},
#                     '1224': {},
#                     '1240': {},
#                     '1241': {},
#                     '1263': {},
#                     '1272': {},
#                     '1288': {},
#                     '1300': {},
#                     '1308': {}}},
#  '2018-2': {'204': {'1321': {},
#                     '1339': {},
#                     '1358': {},
#                     '1377': {},
#                     '1390': {},
#                     '1391': {},
#                     '1410': {},
#                     '1420': {},
#                     '1421': {},
#                     '1436': {},
#                     '1448': {},
#                     '1449': {},
#                     '1482': {},
#                     '1491': {},
#                     '1492': {},
#                     '1512': {},
#                     '1522': {},
#                     '1523': {},
#                     '1540': {},
#                     '1542': {},
#                     '1543': {},
#                     '1561': {}},
#             '205': {'1323': {},
#                     '1335': {},
#                     '1336': {},
#                     '1357': {},
#                     '1384': {},
#                     '1385': {},
#                     '1404': {},
#                     '1408': {},
#                     '1409': {},
#                     '1445': {},
#                     '1456': {},
#                     '1457': {},
#                     '1470': {},
#                     '1497': {},
#                     '1498': {},
#                     '1509': {},
#                     '1514': {},
#                     '1515': {},
#                     '1525': {},
#                     '1530': {},
#                     '1532': {},
#                     '1546': {},
#                     '1548': {}},
#             '206': {'1327': {},
#                     '1345': {},
#                     '1355': {},
#                     '1367': {},
#                     '1383': {},
#                     '1392': {},
#                     '1405': {},
#                     '1411': {},
#                     '1412': {},
#                     '1446': {},
#                     '1460': {},
#                     '1461': {},
#                     '1472': {},
#                     '1500': {},
#                     '1501': {},
#                     '1506': {},
#                     '1516': {},
#                     '1517': {},
#                     '1526': {},
#                     '1531': {},
#                     '1533': {},
#                     '1547': {},
#                     '1549': {}},
#             '207': {'1329': {},
#                     '1346': {},
#                     '1356': {},
#                     '1374': {},
#                     '1388': {},
#                     '1389': {},
#                     '1407': {},
#                     '1417': {},
#                     '1418': {},
#                     '1435': {},
#                     '1458': {},
#                     '1459': {},
#                     '1469': {},
#                     '1484': {},
#                     '1485': {},
#                     '1507': {},
#                     '1518': {},
#                     '1519': {},
#                     '1528': {},
#                     '1537': {},
#                     '1538': {},
#                     '1550': {},
#                     '1557': {}},
#             '208': {'1324': {},
#                     '1325': {},
#                     '1348': {},
#                     '1371': {},
#                     '1375': {},
#                     '1387': {},
#                     '1406': {},
#                     '1415': {},
#                     '1416': {},
#                     '1434': {},
#                     '1450': {},
#                     '1451': {},
#                     '1468': {},
#                     '1480': {},
#                     '1481': {},
#                     '1505': {},
#                     '1510': {},
#                     '1511': {},
#                     '1520': {},
#                     '1521': {},
#                     '1527': {},
#                     '1551': {},
#                     '1559': {}}},
#  '2019-1': {'220': {'1572': {},
#                     '1597': {},
#                     '1610': {},
#                     '1628': {},
#                     '1647': {},
#                     '1648': {},
#                     '1676': {},
#                     '1693': {},
#                     '1694': {},
#                     '1711': {},
#                     '1736': {},
#                     '1737': {},
#                     '1751': {},
#                     '1774': {},
#                     '1775': {},
#                     '1797': {},
#                     '1813': {},
#                     '1814': {},
#                     '1833': {},
#                     '1843': {},
#                     '1858': {},
#                     '1872': {},
#                     '1887': {}},
#             '221': {'1579': {},
#                     '1589': {},
#                     '1591': {},
#                     '1619': {},
#                     '1653': {},
#                     '1654': {},
#                     '1666': {},
#                     '1687': {},
#                     '1688': {},
#                     '1710': {},
#                     '1730': {},
#                     '1731': {},
#                     '1750': {},
#                     '1766': {},
#                     '1767': {},
#                     '1786': {},
#                     '1818': {},
#                     '1819': {},
#                     '1829': {},
#                     '1847': {},
#                     '1848': {},
#                     '1869': {},
#                     '1882': {},
#                     '1886': {}},
#             '222': {'1578': {},
#                     '1601': {},
#                     '1602': {},
#                     '1621': {},
#                     '1642': {},
#                     '1643': {},
#                     '1668': {},
#                     '1684': {},
#                     '1685': {},
#                     '1706': {},
#                     '1728': {},
#                     '1729': {},
#                     '1749': {},
#                     '1760': {},
#                     '1761': {},
#                     '1789': {},
#                     '1815': {},
#                     '1816': {},
#                     '1826': {},
#                     '1845': {},
#                     '1846': {},
#                     '1861': {},
#                     '1876': {}},
#             '223': {'1582': {},
#                     '1594': {},
#                     '1595': {},
#                     '1630': {},
#                     '1644': {},
#                     '1646': {},
#                     '1667': {},
#                     '1679': {},
#                     '1680': {},
#                     '1715': {},
#                     '1716': {},
#                     '1717': {},
#                     '1752': {},
#                     '1764': {},
#                     '1795': {},
#                     '1806': {},
#                     '1807': {},
#                     '1808': {},
#                     '1831': {},
#                     '1834': {},
#                     '1835': {},
#                     '1871': {},
#                     '1888': {}},
#             '224': {'1577': {},
#                     '1596': {},
#                     '1613': {},
#                     '1633': {},
#                     '1649': {},
#                     '1650': {},
#                     '1670': {},
#                     '1691': {},
#                     '1692': {},
#                     '1721': {},
#                     '1734': {},
#                     '1735': {},
#                     '1753': {},
#                     '1771': {},
#                     '1773': {},
#                     '1793': {},
#                     '1811': {},
#                     '1812': {},
#                     '1832': {},
#                     '1850': {},
#                     '1851': {},
#                     '1875': {},
#                     '1884': {},
#                     '1892': {}},
#             '225': {'1573': {},
#                     '1590': {},
#                     '1592': {},
#                     '1616': {},
#                     '1635': {},
#                     '1636': {},
#                     '1662': {},
#                     '1671': {},
#                     '1672': {},
#                     '1708': {},
#                     '1712': {},
#                     '1714': {},
#                     '1745': {},
#                     '1756': {},
#                     '1757': {},
#                     '1791': {},
#                     '1798': {},
#                     '1799': {},
#                     '1828': {},
#                     '1838': {},
#                     '1839': {},
#                     '1859': {},
#                     '1880': {}},
#             '226': {'1575': {},
#                     '1585': {},
#                     '1593': {},
#                     '1618': {},
#                     '1637': {},
#                     '1638': {},
#                     '1664': {},
#                     '1674': {},
#                     '1675': {},
#                     '1709': {},
#                     '1723': {},
#                     '1724': {},
#                     '1747': {},
#                     '1758': {},
#                     '1759': {},
#                     '1785': {},
#                     '1800': {},
#                     '1801': {},
#                     '1822': {},
#                     '1836': {},
#                     '1837': {},
#                     '1863': {},
#                     '1865': {},
#                     '1885': {}},
#             '230': {'1576': {},
#                     '1599': {},
#                     '1624': {},
#                     '1639': {},
#                     '1640': {},
#                     '1641': {},
#                     '1665': {},
#                     '1682': {},
#                     '1683': {},
#                     '1707': {},
#                     '1732': {},
#                     '1738': {},
#                     '1746': {},
#                     '1762': {},
#                     '1763': {},
#                     '1788': {},
#                     '1804': {},
#                     '1805': {},
#                     '1823': {},
#                     '1841': {},
#                     '1842': {},
#                     '1860': {},
#                     '1867': {},
#                     '1877': {}},
#             '231': {'1580': {},
#                     '1581': {},
#                     '1611': {},
#                     '1622': {},
#                     '1651': {},
#                     '1652': {},
#                     '1678': {},
#                     '1689': {},
#                     '1690': {},
#                     '1718': {},
#                     '1719': {},
#                     '1720': {},
#                     '1754': {},
#                     '1769': {},
#                     '1770': {},
#                     '1796': {},
#                     '1809': {},
#                     '1810': {},
#                     '1830': {},
#                     '1852': {},
#                     '1853': {},
#                     '1874': {},
#                     '1883': {},
#                     '1891': {}}}}

# %% [markdown]
# ### Extraindo as características e os valores

# %%
# create assessment features and values
ROOT = '../dataset/workbench/{semester_id}/{class_id}/assessments/'

def extract_feature_value(assessment_file):
    features = []
    for line in assessment_file:
        feature = re.search(r'(\-{4}\s)([a-z\s\_]+)(\:)', line)
        value = re.search(r'([a-z]\:\s)(.+)', line)
        if feature and value:
            feature = feature.group(2)
            feature = re.sub(r'\s', '_', feature)
            features.append(feature)
            value = value.group(2)
            values.append(value)
    return features, values

for semester_id in dataset.keys():
    for class_id in dataset[semester_id].keys():
        path = ROOT.replace('{semester_id}', semester_id)
        path = path.replace('{class_id}', class_id)
        for assessment_id in dataset[semester_id][class_id].keys():
            assessment_file_name = assessment_id+'.data'
            fullpath = os.path.join(path, assessment_file_name)
            features, values = [], []
            with open(fullpath, 'r') as assessment_file:
                features, values = extract_feature_value(assessment_file)
            for feature, value in zip(features, values): 
                #print(f'semester_id={semester_id}, class_id={class_id}, assessment_id={assessment_id}, feature={feature}, value={value}')
                dataset[semester_id][class_id][assessment_id][feature] = value

pprint(dataset)
# Out:
# {'2016-1': {'102': {'106': {'assessment_title': 'Laboratório de Codificação 03 '
#                                                 '– Estrutura de Programação '
#                                                 'Condicional Encadeada',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-19 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-05 12:00',
#                             'total_exercises': '9',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '126': {'assessment_title': 'Avaliação Parcial 03 – '
#                                                 'Estruturas Condicionais '
#                                                 'Encadeadas',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-19 13:20',
#                             'language': 'Python 3',
#                             'start': '2016-07-19 09:55',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '136': {'assessment_title': 'Laboratório de Codificação 04 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Condição',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-02 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-19 12:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '149': {'assessment_title': 'Avaliação Parcial 04 – '
#                                                 'Estrutura de Repetição por '
#                                                 'Condição (while)',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-28 12:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-28 10:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '158': {'assessment_title': 'Laboratório de Codificação 05 '
#                                                 '– Vetores e Strings',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-15 10:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-02 12:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '173': {'assessment_title': 'Avaliação Parcial 05 – '
#                                                 'Vetores e Strings',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-11 11:55',
#                             'language': 'Python 3',
#                             'start': '2016-08-11 10:57',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '18': {'assessment_title': 'Laboratório 0 – Primeiros '
#                                                'passos com o Python',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '102',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-09-08 00:00',
#                            'language': 'Python 3',
#                            'start': '2016-05-31 00:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '184': {'assessment_title': 'Laboratório de Codificação 06 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Contagem',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-30 10:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-16 12:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '199': {'assessment_title': 'Avaliação Parcial 06 – '
#                                                 'Repetição por contagem',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-25 11:55',
#                             'language': 'Python 3',
#                             'start': '2016-08-25 10:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '208': {'assessment_title': 'Laboratório de Codificação 07 '
#                                                 '– Matrizes',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-13 09:55',
#                             'language': 'Python 3',
#                             'start': '2016-08-30 12:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '217': {'assessment_title': 'Avaliação Parcial 07 – '
#                                                 'Matrizes',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '102',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-13 12:45',
#                             'language': 'Python 3',
#                             'start': '2016-09-13 10:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '44': {'assessment_title': 'Laboratório 1 - Variáveis e '
#                                                'Estrutura Sequencial de '
#                                                'Programação',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '102',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-21 10:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-07 12:00',
#                            'total_exercises': '10',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '59': {'assessment_title': 'Avaliação 01 - Variáveis e '
#                                                'Estrutura Sequencial de '
#                                                'Programação',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '102',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-16 11:55',
#                            'language': 'Python 3',
#                            'start': '2016-06-16 10:00',
#                            'total_exercises': '2',
#                            'type': 'exam',
#                            'weight': '1'},
#                     '75': {'assessment_title': 'Laboratório de Codificação 02 '
#                                                '– Estrutura de Programação '
#                                                'Condicional Composta',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '102',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-30 09:59',
#                            'language': 'Python 3',
#                            'start': '2016-06-21 12:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '97': {'assessment_title': 'Avaliação Parcial 02 – '
#                                                'Estrutura Condicional Composta '
#                                                '(sem Aninhamento)',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '102',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-30 11:55',
#                            'language': 'Python 3',
#                            'start': '2016-06-30 10:00',
#                            'total_exercises': '2',
#                            'type': 'exam',
#                            'weight': '1'}},
#             '103': {'103': {'assessment_title': 'Laboratório de Codificação 03 '
#                                                 '– Estrutura de Programação '
#                                                 'Condicional Encadeada',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-19 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-05 10:00',
#                             'total_exercises': '9',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '122': {'assessment_title': 'Avaliação Parcial 03 – '
#                                                 'Estruturas Condicionais '
#                                                 'Encadeadas',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-14 09:55',
#                             'language': 'Python 3',
#                             'start': '2016-07-14 08:55',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '2'},
#                     '131': {'assessment_title': 'Laboratório de Codificação 04 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Condição',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-28 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-19 10:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '148': {'assessment_title': 'Avaliação Parcial 04 – '
#                                                 'Estrutura de Repetição por '
#                                                 'Condição (while)',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-28 09:58',
#                             'language': 'Python 3',
#                             'start': '2016-07-28 09:01',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '2'},
#                     '163': {'assessment_title': 'Laboratório de Codificação 05 '
#                                                 '– Vetores e Strings',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-11 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-02 10:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '174': {'assessment_title': 'Avaliação Parcial 05 – '
#                                                 'Vetores e Strings',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-11 09:55',
#                             'language': 'Python 3',
#                             'start': '2016-08-11 08:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '2'},
#                     '180': {'assessment_title': 'Laboratório de Codificação 06 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Contagem',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-25 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-16 10:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '197': {'assessment_title': 'Avaliação Parcial 06 – '
#                                                 'Repetição por contagem',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-25 09:55',
#                             'language': 'Python 3',
#                             'start': '2016-08-25 08:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '3'},
#                     '205': {'assessment_title': 'Laboratório de Codificação 07 '
#                                                 '– Matrizes',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-13 08:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-30 10:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '216': {'assessment_title': 'Avaliação Parcial 07 – '
#                                                 'Matrizes',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '103',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-13 09:55',
#                             'language': 'Python 3',
#                             'start': '2016-09-13 08:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '3'},
#                     '27': {'assessment_title': 'Laboratório 0 – Primeiros '
#                                                'passos com o Python',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '103',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-07-31 00:00',
#                            'language': 'Python 3',
#                            'start': '2016-05-31 00:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '42': {'assessment_title': 'Laboratório 1 - Variáveis e '
#                                                'Estrutura Sequencial de '
#                                                'Programação',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '103',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-21 08:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-07 10:00',
#                            'total_exercises': '10',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '48': {'assessment_title': 'Avaliação 01 - Variáveis e '
#                                                'Estrutura Sequencial',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '103',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-16 09:55',
#                            'language': 'Python 3',
#                            'start': '2016-06-16 08:00',
#                            'total_exercises': '2',
#                            'type': 'exam',
#                            'weight': '1'},
#                     '74': {'assessment_title': 'Laboratório de Codificação 02 '
#                                                '– Estrutura de Programação '
#                                                'Condicional Composta',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '103',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-30 08:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-21 10:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '94': {'assessment_title': 'Avaliação Parcial 02 – '
#                                                'Estrutura Condicional Composta '
#                                                '(sem Aninhamento)',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '103',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-30 09:55',
#                            'language': 'Python 3',
#                            'start': '2016-06-30 09:00',
#                            'total_exercises': '2',
#                            'type': 'exam',
#                            'weight': '1'}},
#             '105': {'112': {'assessment_title': 'Avaliação Parcial 02 – '
#                                                 'Estrutura Condicional '
#                                                 'Composta (sem Aninhamento)',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-07 20:15',
#                             'language': 'Python 3',
#                             'start': '2016-07-07 18:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '120': {'assessment_title': 'Laboratório de Codificação 03 '
#                                                 '– Estrutura de Programação '
#                                                 'Condicional Encadeada',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-22 23:59',
#                             'language': 'Python 3',
#                             'start': '2016-07-12 20:00',
#                             'total_exercises': '9',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '128': {'assessment_title': 'Avaliação Parcial 02 [Grupo '
#                                                 '2] – Estrutura Condicional '
#                                                 'Composta (sem Aninhamento)',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-14 18:56',
#                             'language': 'Python 3',
#                             'start': '2016-07-14 18:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '140': {'assessment_title': 'Avaliação Parcial 03 – '
#                                                 'Estruturas Condicionais '
#                                                 'Encadeadas',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-21 19:55',
#                             'language': 'Python 3',
#                             'start': '2016-07-21 18:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '144': {'assessment_title': 'Laboratório de Codificação 04 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Condição',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-04 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-26 20:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '165': {'assessment_title': 'Avaliação Parcial 04 – '
#                                                 'Estrutura de Repetição por '
#                                                 'Condição (while) - Versão '
#                                                 'Olímpica :D',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-08 12:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-04 12:00',
#                             'total_exercises': '4',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '177': {'assessment_title': 'Laboratório de Codificação 05 '
#                                                 '– Vetores e Strings',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-18 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-11 20:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '191': {'assessment_title': 'Avaliação Parcial 05 – '
#                                                 'Vetores e Strings',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-18 19:55',
#                             'language': 'Python 3',
#                             'start': '2016-08-18 18:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '192': {'assessment_title': 'Laboratório de Codificação 06 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Contagem',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-01 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-23 20:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '212': {'assessment_title': 'Avaliação Parcial 06 – '
#                                                 'Repetição por contagem',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-01 19:55',
#                             'language': 'Python 3',
#                             'start': '2016-09-01 18:05',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '213': {'assessment_title': 'Laboratório de Codificação 07 '
#                                                 '– Matrizes',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-20 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-09-08 20:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '224': {'assessment_title': 'Avaliação Parcial 07 – '
#                                                 'Matrizes',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '105',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-20 19:55',
#                             'language': 'Python 3',
#                             'start': '2016-09-20 18:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '36': {'assessment_title': 'Laboratório 0 – Primeiros '
#                                                'passos com o Python',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '105',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-06 23:59',
#                            'language': 'Python 3',
#                            'start': '2016-06-02 18:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '54': {'assessment_title': 'Laboratório 1 - Variáveis e '
#                                                'Estrutura Sequencial de '
#                                                'Programação',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '105',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-23 17:59',
#                            'language': 'Python 3',
#                            'start': '2016-06-09 20:00',
#                            'total_exercises': '10',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '83': {'assessment_title': 'Avaliação 01 - Variáveis e '
#                                                'Estrutura Sequencial de '
#                                                'Programação',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '105',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-23 19:55',
#                            'language': 'Python 3',
#                            'start': '2016-06-23 18:00',
#                            'total_exercises': '2',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '98': {'assessment_title': 'Laboratório de Codificação 02 '
#                                                '– Estrutura de Programação '
#                                                'Condicional Composta',
#                            'class_name': 'Introdução à Programação de '
#                                          'Computadores',
#                            'class_number': '105',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-07-07 18:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-28 20:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'}},
#             '106': {'111': {'assessment_title': 'Laboratório de Codificação 03 '
#                                                 '– Estrutura de Programação '
#                                                 'Condicional Encadeada',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-14 20:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-05 22:00',
#                             'total_exercises': '9',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '129': {'assessment_title': 'Avaliação Parcial 03 – '
#                                                 'Estruturas Condicionais '
#                                                 'Encadeadas',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-14 22:05',
#                             'language': 'Python 3',
#                             'start': '2016-07-14 20:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '2'},
#                     '135': {'assessment_title': 'Laboratório de Codificação 04 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Condição',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-28 20:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-19 22:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '152': {'assessment_title': 'Avaliação Parcial 04 – '
#                                                 'Estrutura de Repetição por '
#                                                 'Condição (while)',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-28 22:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-28 20:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '2'},
#                     '162': {'assessment_title': 'Laboratório de Codificação 05 '
#                                                 '– Vetores e Strings',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-11 22:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-02 22:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '175': {'assessment_title': 'Avaliação Parcial 05 – '
#                                                 'Vetores e Strings',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-12 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-11 22:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '2'},
#                     '189': {'assessment_title': 'Laboratório de Codificação 06 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Contagem',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-25 20:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-16 22:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '201': {'assessment_title': 'Avaliação Parcial 06 – '
#                                                 'Repetição por contagem',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-08-25 22:04',
#                             'language': 'Python 3',
#                             'start': '2016-08-25 20:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '3'},
#                     '210': {'assessment_title': 'Laboratório de Codificação 07 '
#                                                 '– Matrizes',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-13 20:00',
#                             'language': 'Python 3',
#                             'start': '2016-08-30 22:00',
#                             'total_exercises': '10',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '220': {'assessment_title': 'Avaliação Parcial 07 – '
#                                                 'Matrizes',
#                             'class_name': 'Introdução à Ciência dos '
#                                           'Computadores',
#                             'class_number': '106',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-09-13 21:59',
#                             'language': 'Python 3',
#                             'start': '2016-09-13 19:59',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '3'},
#                     '51': {'assessment_title': 'Laboratório 0 – Primeiros '
#                                                'passos com o Python',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '106',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-21 20:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-07 20:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '53': {'assessment_title': 'Laboratório 1 - Variáveis e '
#                                                'Estrutura Sequencial de '
#                                                'Programação',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '106',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-21 20:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-09 18:00',
#                            'total_exercises': '10',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '63': {'assessment_title': 'Avaliação 01 - Variáveis e '
#                                                'Estrutura Sequencial',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '106',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-16 22:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-16 20:00',
#                            'total_exercises': '2',
#                            'type': 'exam',
#                            'weight': '1'},
#                     '71': {'assessment_title': 'Laboratório de Codificação 02 '
#                                                '– Estrutura de Programação '
#                                                'Condicional Composta',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '106',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-30 22:00',
#                            'language': 'Python 3',
#                            'start': '2016-06-21 20:00',
#                            'total_exercises': '7',
#                            'type': 'homework',
#                            'weight': '1'},
#                     '93': {'assessment_title': 'Avaliação Parcial 02 – '
#                                                'Estrutura Condicional Composta '
#                                                '(sem Aninhamento)',
#                            'class_name': 'Introdução à Ciência dos '
#                                          'Computadores',
#                            'class_number': '106',
#                            'codemirror_mode': 'python/python.js',
#                            'end': '2016-06-30 22:05',
#                            'language': 'Python 3',
#                            'start': '2016-06-30 20:00',
#                            'total_exercises': '2',
#                            'type': 'exam',
#                            'weight': '1'}},
#             '107': {'107': {'assessment_title': 'Laboratório de Codificação 03 '
#                                                 '– Estrutura de Programação '
#                                                 'Condicional Encadeada',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '107',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-14 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-05 20:00',
#                             'total_exercises': '9',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '127': {'assessment_title': 'Avaliação Parcial 03 – '
#                                                 'Estruturas Condicionais '
#                                                 'Encadeadas',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '107',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-14 20:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-14 18:00',
#                             'total_exercises': '2',
#                             'type': 'exam',
#                             'weight': '1'},
#                     '137': {'assessment_title': 'Laboratório de Codificação 04 '
#                                                 '– Estrutura de Programação de '
#                                                 'Repetição por Condição',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
#                             'class_number': '107',
#                             'codemirror_mode': 'python/python.js',
#                             'end': '2016-07-28 18:00',
#                             'language': 'Python 3',
#                             'start': '2016-07-19 20:00',
#                             'total_exercises': '11',
#                             'type': 'homework',
#                             'weight': '1'},
#                     '150': {'assessment_title': 'Avaliação Parcial 04 – '
#                                                 'Estrutura de Repetição por '
#                                                 'Condição (while)',
#                             'class_name': 'Introdução à Programação de '
#                                           'Computadores',
# ...
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1581': {'assessment_title': 'Lab 1 – Estrutura Sequencial '
#                                                  'e Variáveis - 2019',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-04-02 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-03-19 16:00',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1611': {'assessment_title': 'Desafios 1 - Estrutura '
#                                                  'Sequencial e Variáveis -19',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-30 00:00',
#                              'language': 'Python 3',
#                              'start': '2019-03-26 00:00',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1622': {'assessment_title': 'TP1: Variáveis e Estrutura '
#                                                  'Sequencial',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-04-02 19:55',
#                              'language': 'Python 3',
#                              'start': '2019-04-02 19:00',
#                              'total_exercises': '2',
#                              'type': 'exam',
#                              'weight': '1'},
#                     '1651': {'assessment_title': 'Lab 2 – Estrutura '
#                                                  'Condicional Simples',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-04-16 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-04-04 19:50',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1652': {'assessment_title': 'Desafios 2 - Estruturas '
#                                                  'Condicionais',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-30 00:00',
#                              'language': 'Python 3',
#                              'start': '2019-04-04 19:50',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1678': {'assessment_title': 'TP2 - Estrutura Condicional '
#                                                  'Simples e Composta',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-04-16 19:50',
#                              'language': 'Python 3',
#                              'start': '2019-04-16 18:54',
#                              'total_exercises': '2',
#                              'type': 'exam',
#                              'weight': '1'},
#                     '1689': {'assessment_title': 'Lab 3 – Condicionais '
#                                                  'Encadeados (if/elif)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-05-02 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-04-23 19:40',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1690': {'assessment_title': 'Desafios 3 - Condicionais '
#                                                  'Encadeados (if/elif)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-30 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-04-23 19:40',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1718': {'assessment_title': 'TP3 - Estrutura Condicional '
#                                                  'Encadeada',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-05-02 19:50',
#                              'language': 'Python 3',
#                              'start': '2019-05-02 18:06',
#                              'total_exercises': '2',
#                              'type': 'exam',
#                              'weight': '2'},
#                     '1719': {'assessment_title': 'Lab 4 – Repetição por '
#                                                  'Condição (while)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-05-16 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-05-07 19:40',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1720': {'assessment_title': 'Desafios 4 – Repetição por '
#                                                  'Condição (while)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-30 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-05-07 19:40',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1754': {'assessment_title': 'TP4: Estrutura de Repetição '
#                                                  'por Condição (while)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-05-16 19:55',
#                              'language': 'Python 3',
#                              'start': '2019-05-16 18:05',
#                              'total_exercises': '2',
#                              'type': 'exam',
#                              'weight': '2'},
#                     '1769': {'assessment_title': 'Lab 5 – Vetores e Strings',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-05-30 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-05-21 19:40',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1770': {'assessment_title': 'Desafios 5 - Vetores e '
#                                                  'Strings',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-30 00:00',
#                              'language': 'Python 3',
#                              'start': '2019-05-21 19:40',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1796': {'assessment_title': 'TP5: Vetores e Strings',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-05-30 19:50',
#                              'language': 'Python 3',
#                              'start': '2019-05-30 18:03',
#                              'total_exercises': '3',
#                              'type': 'exam',
#                              'weight': '3'},
#                     '1809': {'assessment_title': 'Desafios 6 - Repetição por '
#                                                  'Contagem (for)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-09-04 00:00',
#                              'language': 'Python 3',
#                              'start': '2019-06-04 19:00',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1810': {'assessment_title': 'Lab 6 – Repetição por '
#                                                  'Contagem (for)',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-06-13 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-06-04 19:00',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1830': {'assessment_title': 'TP6: Repetição por contagem',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-06-13 19:50',
#                              'language': 'Python 3',
#                              'start': '2019-06-13 18:03',
#                              'total_exercises': '3',
#                              'type': 'exam',
#                              'weight': '3'},
#                     '1852': {'assessment_title': 'Lab 7 – Matrizes',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-02 18:00',
#                              'language': 'Python 3',
#                              'start': '2019-06-18 19:00',
#                              'total_exercises': '12',
#                              'type': 'homework',
#                              'weight': '1'},
#                     '1853': {'assessment_title': 'Exercícios de Desafio 7: '
#                                                  'Matrizes',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-08-29 00:00',
#                              'language': 'Python 3',
#                              'start': '2019-06-18 19:00',
#                              'total_exercises': '3',
#                              'type': 'homework',
#                              'weight': '0'},
#                     '1874': {'assessment_title': 'TP 7: Matrizes',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-02 19:50',
#                              'language': 'Python 3',
#                              'start': '2019-07-02 18:03',
#                              'total_exercises': '2',
#                              'type': 'exam',
#                              'weight': '3'},
#                     '1883': {'assessment_title': 'TP Substitutivo - EME01',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-04 19:50',
#                              'language': 'Python 3',
#                              'start': '2019-07-04 18:03',
#                              'total_exercises': '3',
#                              'type': 'exam',
#                              'weight': '0'},
#                     '1891': {'assessment_title': 'Prova Final',
#                              'class_name': 'Introdução à Programação de '
#                                            'Computadores',
#                              'class_number': '231',
#                              'codemirror_mode': 'python/python.js',
#                              'end': '2019-07-09 19:53',
#                              'language': 'Python 3',
#                              'start': '2019-07-09 18:02',
#                              'total_exercises': '2',
#                              'type': 'exam',
#                              'weight': '0'}}}}

# %% [markdown]
# ## Inserido dados no banco de dados

# %% [markdown]
# ### Estabelecendo conxeão

# %%
def connection_database():
    connection = pymysql.connect(host='localhost',
                             user='root',
                             password='open',
                             db='dataset-workbench',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
    return connection

# %% [markdown]
# ### Gravando no banco

# %%
conn = connection_database()
cursor = conn.cursor()

for semester_id in dataset.keys():
    for class_id in dataset[semester_id].keys():
        for assessment_id in dataset[semester_id][class_id].keys():
            features = f"assessment_id, semester_id, "
            values = f"'{semester_id}#{class_id}#{assessment_id}', '{semester_id}', "
            for feature in dataset[semester_id][class_id][assessment_id].keys():
                feature_value = dataset[semester_id][class_id][assessment_id][feature] 
                return_search = re.search(r'\d+\:\d+', feature_value)
                if return_search:
                    hour = return_search.group(0)
                    new_hour = hour+':00'
                    feature_value = feature_value.replace(hour, new_hour)

                features += f"{feature}, "
                if feature in ['assessment_title', 'class_name',
                                'start', 'end', 'language', 'codemirror_mode',
                                'type']:
                    values += f"'{feature_value}', "
                else:
                    values += f"{feature_value}, "
            insert_assessment = f"INSERT INTO assessment ({features[:-2]}) VALUES ({values[:-2]})"
            print(insert_assessment)
            cursor.execute(insert_assessment)

conn.commit()
conn.close()
# Out:
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1434', '2018-2', 'TP 3 - Condicionais Encadeadas (if/elif/else)', 'Introdução à Programação de Computadores', 208, '2018-09-25 08:00:00', '2018-09-25 10:10:00', 'Python 3', 'python/python.js', 'exam', 2, 3
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1481', '2018-2', 'Desafios 5 - Vetores e Strings', 'Introdução à Programação de Computadores', 208, '2018-10-11 09:55:00', '2018-12-23 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1375', '2018-2', 'Lab 2 – Estrutura Condicional Simples', 'Introdução à Programação de Computadores', 208, '2018-08-28 10:00:00', '2018-09-11 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1520', '2018-2', 'Desafio 7 -  Matrizes', 'Introdução à Programação de Computadores', 208, '2018-11-22 09:00:00', '2018-12-23 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1325', '2018-2', 'Lab 1 – Variáveis e Estrutura Sequencial', 'Introdução à Programação de Computadores', 208, '2018-08-14 09:20:00', '2018-08-23 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1451', '2018-2', 'Desafios 4 – Repetição por Condição (while)', 'Introdução à Programação de Computadores', 208, '2018-09-27 10:00:00', '2018-12-11 08:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1468', '2018-2', 'TP 4: Estrutura de Repetição por Condição (while)', 'Introdução à Programação de Computadores', 208, '2018-10-09 08:00:00', '2018-10-09 09:55:00', 'Python 3', 'python/python.js', 'exam', 2, 3
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1324', '2018-2', 'Lab 0 – Primeiros passos com o Python', 'Introdução à Programação de Computadores', 208, '2018-08-07 08:00:00', '2018-10-11 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 14
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1416', '2018-2', 'Desafios 3 - Condicionais Encadeados (if/elif)', 'Introdução à Programação de Computadores', 208, '2018-09-13 08:00:00', '2018-12-11 08:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1559', '2018-2', 'Prova Final', 'Introdução à Programação de Computadores', 208, '2018-12-11 08:00:00', '2018-12-11 09:50:00', 'Python 3', 'python/python.js', 'exam', 0, 3
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1505', '2018-2', 'TP 5: Vetores e Strings', 'Introdução à Programação de Computadores', 208, '2018-10-30 08:00:00', '2018-10-30 09:55:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1348', '2018-2', 'Desafios 1 - Variáveis e Estrutura Sequencial', 'Introdução à Programação de Computadores', 208, '2018-08-16 09:00:00', '2018-12-23 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1521', '2018-2', 'Lab 7 – Matrizes', 'Introdução à Programação de Computadores', 208, '2018-11-22 09:00:00', '2018-12-04 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1480', '2018-2', 'Lab 5 – Vetores e Strings', 'Introdução à Programação de Computadores', 208, '2018-10-11 09:55:00', '2018-11-01 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1387', '2018-2', 'Desafios 2 - Estruturas Condicionais', 'Introdução à Programação de Computadores', 208, '2018-08-30 09:45:00', '2018-12-23 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1527', '2018-2', 'TP 6: Estrutura de Repetição por Contagem (for)', 'Introdução à Programação de Computadores', 208, '2018-11-13 08:00:00', '2018-11-13 09:55:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1415', '2018-2', 'Lab 3 – Condicionais Encadeados (if/elif)', 'Introdução à Programação de Computadores', 208, '2018-09-13 08:00:00', '2018-09-25 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1510', '2018-2', 'Lab 6 – Repetição por Contagem (for)', 'Introdução à Programação de Computadores', 208, '2018-11-01 10:00:00', '2018-11-13 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1511', '2018-2', 'Desafios 6 - Repetição por Contagem (for)', 'Introdução à Programação de Computadores', 208, '2018-11-01 10:00:00', '2018-12-23 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1450', '2018-2', 'Lab 4 – Repetição por Condição (while)', 'Introdução à Programação de Computadores', 208, '2018-09-27 10:00:00', '2018-10-09 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1406', '2018-2', 'TP 2 - Condicional Simples e Composta (if/else)', 'Introdução à Programação de Computadores', 208, '2018-09-11 09:00:00', '2018-09-11 09:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1551', '2018-2', 'TP 7: Matrizes', 'Introdução à Programação de Computadores', 208, '2018-12-04 08:00:00', '2018-12-04 09:55:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=208, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#208#1371', '2018-2', 'TP 1: Variáveis e Estrutura Sequencial', 'Introdução à Programação de Computadores', 208, '2018-08-23 09:00:00', '2018-08-23 09:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1506', '2018-2', 'TP 5: Vetores e Strings', 'Introdução à Ciência dos Computadores', 206, '2018-11-08 16:30:00', '2018-11-08 18:30:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1501', '2018-2', 'Desafios 5 - Vetores e Strings', 'Introdução à Ciência dos Computadores', 206, '2018-10-25 00:00:00', '2018-11-19 10:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1383', '2018-2', 'Lab 2 – Estrutura Condicional Simples', 'Introdução à Ciência dos Computadores', 206, '2018-08-27 09:45:00', '2018-09-10 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1405', '2018-2', 'TP 2 - Condicional Simples e Composta (if/else)', 'Introdução à Ciência dos Computadores', 206, '2018-09-11 18:30:00', '2018-09-11 19:30:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1461', '2018-2', 'Desafios 4 – Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 206, '2018-10-01 12:00:00', '2018-11-19 10:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1412', '2018-2', 'Lab 3 – Condicionais Encadeados (if/elif)', 'Introdução à Ciência dos Computadores', 206, '2018-09-12 00:00:00', '2018-09-26 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1446', '2018-2', 'TP 3 - Condicionais Encadeadas (if/elif/else)', 'Introdução à Ciência dos Computadores', 206, '2018-09-27 18:30:00', '2018-09-27 19:30:00', 'Python 3', 'python/python.js', 'exam', 2, 2
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1345', '2018-2', 'Lab01– Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 206, '2018-08-13 00:00:00', '2018-08-22 00:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1460', '2018-2', 'Lab 4 – Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 206, '2018-10-01 12:00:00', '2018-10-10 00:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1516', '2018-2', 'Lab 6 – Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 206, '2018-11-07 12:00:00', '2018-11-21 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1526', '2018-2', 'TP 6: Estrutura de Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 206, '2018-11-19 10:00:00', '2018-11-19 11:50:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1472', '2018-2', 'TP 4: Estrutura de Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 206, '2018-10-18 18:45:00', '2018-10-18 20:00:00', 'Python 3', 'python/python.js', 'exam', 2, 3
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1411', '2018-2', 'Desafios 3 - Condicionais Encadeados (if/elif)', 'Introdução à Ciência dos Computadores', 206, '2018-09-12 12:00:00', '2018-11-30 00:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1533', '2018-2', 'Desafio 7 -  Matrizes', 'Introdução à Ciência dos Computadores', 206, '2018-11-21 12:00:00', '2018-12-03 10:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1367', '2018-2', 'TP 1: Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 206, '2018-08-22 11:05:00', '2018-08-22 11:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1327', '2018-2', 'Lab0 – Primeiros passos com o Python', 'Introdução à Ciência dos Computadores', 206, '2018-08-06 00:00:00', '2018-08-22 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 14
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1547', '2018-2', 'TP 7: Matrizes', 'Introdução à Ciência dos Computadores', 206, '2018-12-03 10:00:00', '2018-12-03 11:50:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1531', '2018-2', 'Lab 7 – Matrizes', 'Introdução à Ciência dos Computadores', 206, '2018-11-21 12:00:00', '2018-12-05 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1549', '2018-2', 'Prova Final', 'Introdução à Ciência dos Computadores', 206, '2018-12-10 10:00:00', '2018-12-10 11:55:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1500', '2018-2', 'Lab 5 – Vetores e Strings', 'Introdução à Ciência dos Computadores', 206, '2018-10-25 00:00:00', '2018-11-05 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1517', '2018-2', 'Desafios 6 - Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 206, '2018-11-07 12:00:00', '2018-11-19 10:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1355', '2018-2', 'Desafios 1 - Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 206, '2018-08-06 00:00:00', '2018-12-23 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=206, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#206#1392', '2018-2', 'Desafios 2 - Estruturas Condicionais', 'Introdução à Ciência dos Computadores', 206, '2018-08-29 00:00:00', '2018-12-13 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1525', '2018-2', 'TP 6: Estrutura de Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 205, '2018-11-19 10:00:00', '2018-11-19 11:50:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1409', '2018-2', 'Desafios 3 - Condicionais Encadeados (if/elif)', 'Introdução à Ciência dos Computadores', 205, '2018-09-12 11:50:00', '2018-12-23 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1515', '2018-2', 'Desafios 6 - Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 205, '2018-11-07 10:00:00', '2018-12-24 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1323', '2018-2', 'Lab 0 – Primeiros passos com o Python', 'Introdução à Ciência dos Computadores', 205, '2018-08-06 10:00:00', '2018-10-11 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 14
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1456', '2018-2', 'Lab 4 – Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 205, '2018-10-01 11:50:00', '2018-10-10 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1532', '2018-2', 'Desafio 7 -  Matrizes', 'Introdução à Ciência dos Computadores', 205, '2018-11-21 12:00:00', '2018-12-03 10:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1445', '2018-2', 'TP 3 - Condicionais Encadeadas (if/elif/else)', 'Introdução à Ciência dos Computadores', 205, '2018-09-26 10:00:00', '2018-09-26 11:50:00', 'Python 3', 'python/python.js', 'exam', 2, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1470', '2018-2', 'TP 4: Estrutura de Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 205, '2018-10-10 10:00:00', '2018-10-10 11:50:00', 'Python 3', 'python/python.js', 'exam', 2, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1530', '2018-2', 'Lab 7 – Matrizes', 'Introdução à Ciência dos Computadores', 205, '2018-11-21 12:00:00', '2018-12-05 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1497', '2018-2', 'Lab 5 – Vetores e Strings', 'Introdução à Ciência dos Computadores', 205, '2018-10-22 11:50:00', '2018-11-05 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1457', '2018-2', 'Desafios 4 – Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 205, '2018-10-01 11:50:00', '2018-12-23 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1404', '2018-2', 'TP 2 - Condicional Simples e Composta (if/else)', 'Introdução à Ciência dos Computadores', 205, '2018-09-10 10:00:00', '2018-09-10 11:50:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1546', '2018-2', 'TP 7: Matrizes', 'Introdução à Ciência dos Computadores', 205, '2018-12-03 10:00:00', '2018-12-03 11:50:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1408', '2018-2', 'Lab 3 – Condicionais Encadeados (if/elif)', 'Introdução à Ciência dos Computadores', 205, '2018-09-12 11:50:00', '2018-09-24 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1514', '2018-2', 'Lab 6 – Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 205, '2018-11-07 12:00:00', '2018-11-21 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1548', '2018-2', 'Prova Final', 'Introdução à Ciência dos Computadores', 205, '2018-12-05 10:10:00', '2018-12-05 12:00:00', 'Python 3', 'python/python.js', 'exam', 0, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1509', '2018-2', 'TP 5: Vetores e Strings', 'Introdução à Ciência dos Computadores', 205, '2018-11-05 10:05:00', '2018-11-05 12:00:00', 'Python 3', 'python/python.js', 'exam', 3, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1498', '2018-2', 'Desafios 5 - Vetores e Strings', 'Introdução à Ciência dos Computadores', 205, '2018-10-22 11:50:00', '2018-12-21 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1357', '2018-2', 'TP 1: Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 205, '2018-08-22 10:00:00', '2018-08-22 11:50:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1385', '2018-2', 'Desafios 2 - Estruturas Condicionais', 'Introdução à Ciência dos Computadores', 205, '2018-08-27 11:50:00', '2018-12-23 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 6
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1384', '2018-2', 'Lab 2 – Estrutura Condicional Simples', 'Introdução à Ciência dos Computadores', 205, '2018-08-27 11:50:00', '2018-09-10 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1335', '2018-2', 'Lab 01 – Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 205, '2018-08-08 11:20:00', '2018-08-22 10:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=205, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#205#1336', '2018-2', 'Desafios 1 - Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 205, '2018-08-13 11:20:00', '2018-12-23 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1389', '2018-2', 'Desafios 2 - Estruturas Condicionais', 'Introdução à Ciência dos Computadores', 207, '2018-08-27 22:00:00', '2018-12-19 20:00:00', 'Python 3', 'python/python.js', 'homework', 0, 6
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1374', '2018-2', 'TP 1: Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 207, '2018-08-22 21:00:00', '2018-08-22 21:50:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1356', '2018-2', 'Desafios 1 - Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 207, '2018-08-13 00:00:00', '2018-12-23 23:59:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1388', '2018-2', 'Lab 2 – Estrutura Condicional Simples', 'Introdução à Ciência dos Computadores', 207, '2018-08-27 22:00:00', '2018-09-10 20:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1435', '2018-2', 'TP 3 - Condicionais Encadeadas (if/elif/else)', 'Introdução à Ciência dos Computadores', 207, '2018-09-24 21:10:00', '2018-09-24 22:00:00', 'Python 3', 'python/python.js', 'exam', 2, 2
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1418', '2018-2', 'Desafios 3 - Condicionais Encadeados (if/elif)', 'Introdução à Ciência dos Computadores', 207, '2018-09-12 22:00:00', '2018-12-12 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1458', '2018-2', 'Lab 4 – Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 207, '2018-10-01 17:00:00', '2018-10-08 20:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1485', '2018-2', 'Desafios 5 - Vetores e Strings', 'Introdução à Ciência dos Computadores', 207, '2018-10-10 22:00:00', '2018-12-19 20:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1507', '2018-2', 'TP 5: Vetores e Strings', 'Introdução à Ciência dos Computadores', 207, '2018-10-31 20:00:00', '2018-10-31 21:10:00', 'Python 3', 'python/python.js', 'exam', 3, 2
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1346', '2018-2', 'Lab 01 – Variáveis e Estrutura Sequencial', 'Introdução à Ciência dos Computadores', 207, '2018-08-15 21:00:00', '2018-08-22 20:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1329', '2018-2', 'Lab Codificação 0 – Primeiros passos com o Python', 'Introdução à Ciência dos Computadores', 207, '2018-08-06 20:00:00', '2018-10-11 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 14
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1469', '2018-2', 'TP 4: Estrutura de Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 207, '2018-10-08 20:10:00', '2018-10-08 21:25:00', 'Python 3', 'python/python.js', 'exam', 2, 2
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1407', '2018-2', 'TP 2 - Condicional Simples e Composta (if/else)', 'Introdução à Ciência dos Computadores', 207, '2018-09-10 21:00:00', '2018-09-10 21:50:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1528', '2018-2', 'TP 6: Estrutura de Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 207, '2018-11-14 20:00:00', '2018-11-14 21:10:00', 'Python 3', 'python/python.js', 'exam', 3, 2
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1557', '2018-2', 'Prova Final', 'Introdução à Ciência dos Computadores', 207, '2018-12-05 20:05:00', '2018-12-05 21:20:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1518', '2018-2', 'Lab 6 – Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 207, '2018-11-05 22:00:00', '2018-11-14 20:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1519', '2018-2', 'Desafios 6 - Repetição por Contagem (for)', 'Introdução à Ciência dos Computadores', 207, '2018-11-05 22:00:00', '2018-12-19 20:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1417', '2018-2', 'Lab 3 – Condicionais Encadeados (if/elif)', 'Introdução à Ciência dos Computadores', 207, '2018-09-12 22:00:00', '2018-09-24 20:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1550', '2018-2', 'Trabalho Pratico 7', 'Introdução à Ciência dos Computadores', 207, '2018-12-03 20:15:00', '2018-12-03 21:15:00', 'Python 3', 'python/python.js', 'exam', 3, 2
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1538', '2018-2', 'Desafio 7 -  Matrizes', 'Introdução à Ciência dos Computadores', 207, '2018-11-21 22:00:00', '2018-12-12 22:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1537', '2018-2', 'Lab 7 – Matrizes', 'Introdução à Ciência dos Computadores', 207, '2018-11-21 20:00:00', '2018-12-05 20:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1484', '2018-2', 'Lab 5 – Vetores e Strings', 'Introdução à Ciência dos Computadores', 207, '2018-10-10 22:00:00', '2018-10-31 22:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=207, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#207#1459', '2018-2', 'Desafios 4 – Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 207, '2018-10-01 16:00:00', '2018-12-18 00:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1523', '2018-2', 'Desafios 6 - Repetição por Contagem (for)', 'Introdução à Programação de Computadores', 204, '2018-11-08 16:00:00', '2018-11-27 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1561', '2018-2', 'TP 7: Matrizes', 'Introdução à Programação de Computadores', 204, '2018-12-13 14:00:00', '2018-12-13 16:00:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1377', '2018-2', 'TP 1: Variáveis e Estrutura Sequencial', 'Introdução à Programação de Computadores', 204, '2018-09-11 14:00:00', '2018-09-11 15:55:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1492', '2018-2', 'Lab 5 – Vetores e Strings', 'Introdução à Programação de Computadores', 204, '2018-10-23 00:00:00', '2018-11-06 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1358', '2018-2', 'Desafios 1 - Variáveis e Estrutura Sequencial', 'Introdução à Programação de Computadores', 204, '2018-08-21 00:00:00', '2018-09-30 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1491', '2018-2', 'Desafios 5 - Vetores e Strings', 'Introdução à Programação de Computadores', 204, '2018-10-23 00:00:00', '2018-11-06 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1436', '2018-2', 'TP 3 - Condicionais Encadeadas (if/elif/else)', 'Introdução à Programação de Computadores', 204, '2018-09-25 14:00:00', '2018-09-25 15:59:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1482', '2018-2', 'TP 4: Estrutura de Repetição por Condição (while)', 'Introdução à Programação de Computadores', 204, '2018-10-11 14:00:00', '2018-10-11 15:59:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1421', '2018-2', 'Desafios 3 - Condicionais Encadeados (if/elif)', 'Introdução à Programação de Computadores', 204, '2018-09-13 00:00:00', '2018-09-25 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1448', '2018-2', 'Desafios 4 – Repetição por Condição (while)', 'Introdução à Programação de Computadores', 204, '2018-09-27 00:00:00', '2018-10-11 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1512', '2018-2', 'TP 5: Vetores e Strings', 'Introdução à Programação de Computadores', 204, '2018-11-06 14:00:00', '2018-11-06 15:59:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1390', '2018-2', 'Lab 2 – Estrutura Condicional Simples', 'Introdução à Programação de Computadores', 204, '2018-08-28 00:00:00', '2018-09-11 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1420', '2018-2', 'Lab 3 – Condicionais Encadeados (if/elif)', 'Introdução à Programação de Computadores', 204, '2018-09-13 00:00:00', '2018-09-25 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1410', '2018-2', 'TP 2 - Condicional Simples e Composta (if/else)', 'Introdução à Programação de Computadores', 204, '2018-09-20 14:00:00', '2018-09-20 15:55:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1391', '2018-2', 'Desafios 2 - Estruturas Condicionais', 'Introdução à Programação de Computadores', 204, '2018-08-28 00:00:00', '2018-09-06 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 6
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1339', '2018-2', 'Lab 01 – Variáveis e Estrutura Sequencial', 'Introdução à Programação de Computadores', 204, '2018-08-09 15:00:00', '2018-09-30 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1449', '2018-2', 'Lab 4 – Repetição por Condição (while)', 'Introdução à Programação de Computadores', 204, '2018-09-27 00:00:00', '2018-10-11 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1321', '2018-2', 'Lab 0 – Primeiros passos com o Python', 'Introdução à Programação de Computadores', 204, '2018-08-02 00:00:00', '2018-09-30 00:00:00', 'Python 3', 'python/python.js', 'homework', 1, 14
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1540', '2018-2', 'TP 6: Estrutura de Repetição por Contagem (for)', 'Introdução à Programação de Computadores', 204, '2018-11-27 14:00:00', '2018-11-27 16:05:00', 'Python 3', 'python/python.js', 'exam', 1, 3
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1522', '2018-2', 'Lab 6 – Repetição por Contagem (for)', 'Introdução à Programação de Computadores', 204, '2018-11-08 15:00:00', '2018-11-27 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1543', '2018-2', 'Desafio 7 -  Matrizes', 'Introdução à Programação de Computadores', 204, '2018-11-29 00:00:00', '2018-12-13 14:00:00', 'Python 3', 'python/python.js', 'homework', 0, 13
# semester_id=2018-2, class_id=204, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2018-2#204#1542', '2018-2', 'Lab 7 – Matrizes', 'Introdução à Programação de Computadores', 204, '2018-11-29 00:00:00', '2018-12-13 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2016-2, class_id=122, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2016-2#122#248', '2016-2', 'Laboratório de Codificação 01 – Variáveis e Estrutura Sequencial de Programação', 'Introdução à Programação de Computadores', 122, '2016-10-20 15:00:00', '2016-11-03 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# ...
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#670', '2017-1', 'Trabalho Prático 5: Vetores e Strings', 'Introdução à Ciência dos Computadores', 138, '2017-06-01 08:00:00', '2017-06-01 09:20:00', 'Python 3', 'python/python.js', 'exam', 3, 2
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#548', '2017-1', 'Exercícios de Desafio 3: Estruturas Encadeadas', 'Introdução à Ciência dos Computadores', 138, '2017-04-25 10:00:00', '2017-05-09 07:59:00', 'Python 3', 'python/python.js', 'homework', 1, 6
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#574', '2017-1', 'Trabalho Prático 3: Estruturas Condicionais Encadeadas', 'Introdução à Ciência dos Computadores', 138, '2017-05-04 08:00:00', '2017-05-04 09:25:00', 'Python 3', 'python/python.js', 'exam', 2, 2
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#782', '2017-1', 'Trabalho Prático Substitutivo', 'Introdução à Ciência dos Computadores', 138, '2017-07-13 08:30:00', '2017-07-13 09:30:00', 'Python 3', 'python/python.js', 'exam', 0, 2
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#781', '2017-1', 'Trabalho Prático 7: Matrizes', 'Introdução à Ciência dos Computadores', 138, '2017-07-11 08:30:00', '2017-07-11 09:50:00', 'Python 3', 'python/python.js', 'exam', 3, 2
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#638', '2017-1', 'Laboratório de Codificação 05 – Vetores e Strings', 'Introdução à Ciência dos Computadores', 138, '2017-05-23 10:00:00', '2017-07-08 07:59:00', 'Python 3', 'python/python.js', 'homework', 1, 11
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#480', '2017-1', 'Trabalho Prático 01: Variáveis e Estrutura Sequencial de Programação', 'Introdução à Ciência dos Computadores', 138, '2017-04-04 08:00:00', '2017-04-04 09:25:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#666', '2017-1', 'Exercícios de Desafio 5: Vetores e Strings', 'Introdução à Ciência dos Computadores', 138, '2017-05-23 10:00:00', '2017-06-06 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 5
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#730', '2017-1', 'Laboratório de Codificação 07 – Matrizes', 'Introdução à Ciência dos Computadores', 138, '2017-06-22 10:00:00', '2017-07-11 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 10
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#613', '2017-1', 'Trabalho Prático 4: Estrutura de Repetição por Condição (while)', 'Introdução à Ciência dos Computadores', 138, '2017-05-18 08:00:00', '2017-05-18 09:15:00', 'Python 3', 'python/python.js', 'exam', 2, 2
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#437', '2017-1', 'Laboratório de Codificação 01 – Variáveis e Estrutura Sequencial de Programação', 'Introdução à Ciência dos Computadores', 138, '2017-03-21 10:00:00', '2017-07-08 00:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#502', '2017-1', 'Exercícios de Desafio 2: Estruturas Condicionais Simples e Compostas', 'Introdução à Ciência dos Computadores', 138, '2017-04-06 10:00:00', '2017-04-25 07:59:00', 'Python 3', 'python/python.js', 'homework', 1, 6
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#590', '2017-1', 'Exercícios de Desafio 4: Estrutura de Programação de Repetição por Condição', 'Introdução à Ciência dos Computadores', 138, '2017-05-11 09:00:00', '2017-05-22 08:00:00', 'Python 3', 'python/python.js', 'homework', 1, 8
# semester_id=2017-1, class_id=138, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#138#691', '2017-1', 'Exercícios de Desafio 6: Repetição por Contagem', 'Introdução à Ciência dos Computadores', 138, '2017-06-06 10:00:00', '2017-06-22 07:50:00', 'Python 3', 'python/python.js', 'homework', 1, 5
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#746', '2017-1', 'Exercícios de Desafio 7: Matrizes', 'Introdução à Programação de Computadores', 135, '2017-06-26 16:00:00', '2017-07-10 16:00:00', 'Python 3', 'python/python.js', 'homework', 1, 3
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#546', '2017-1', 'Laboratório de Codificação 03 – Estrutura de Programação Condicional Encadeada', 'Introdução à Programação de Computadores', 135, '2017-05-03 16:00:00', '2017-05-03 23:59:00', 'Python 3', 'python/python.js', 'homework', 1, 9
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#611', '2017-1', 'Trabalho Prático 4: Estrutura de Repetição por Condição (while)', 'Introdução à Programação de Computadores', 135, '2017-05-17 15:00:00', '2017-05-17 15:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#559', '2017-1', 'Trabalho Prático 3: Estruturas Condicionais Encadeadas', 'Introdução à Programação de Computadores', 135, '2017-05-03 15:00:00', '2017-05-03 15:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#409', '2017-1', 'Laboratório de Codificação 0 – Primeiros passos com o Python', 'Introdução à Programação de Computadores', 135, '2017-03-13 15:00:00', '2017-06-23 00:00:00', 'Python 3', 'python/python.js', 'homework', 1, 14
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#608', '2017-1', 'Exercícios de Desafio 4: Estrutura de Programação de Repetição por Condição', 'Introdução à Programação de Computadores', 135, '2017-05-08 00:00:00', '2017-05-24 18:00:00', 'Python 3', 'python/python.js', 'homework', 1, 8
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#744', '2017-1', 'Trabalho Prático 7: Matrizes', 'Introdução à Programação de Computadores', 135, '2017-07-18 14:00:00', '2017-07-18 14:29:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#429', '2017-1', 'Exercícios de Desafio 1: Variáveis e Estrutura Sequencial de Programação', 'Introdução à Programação de Computadores', 135, '2017-03-20 16:00:00', '2017-04-05 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 7
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#682', '2017-1', 'Exercícios de Desafio 6: Repetição por Contagem', 'Introdução à Programação de Computadores', 135, '2017-06-05 16:00:00', '2017-06-19 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 5
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#769', '2017-1', 'Trabalho Prático Substitutivo', 'Introdução à Programação de Computadores', 135, '2017-07-18 14:00:00', '2017-07-18 15:50:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#683', '2017-1', 'Laboratório de Codificação 06 – Estrutura de Programação de Repetição por Contagem', 'Introdução à Programação de Computadores', 135, '2017-06-05 14:30:00', '2017-06-19 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 10
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#518', '2017-1', 'Trabalho Prático 02 - Estrutura Condicional Simples e Composta', 'Introdução à Programação de Computadores', 135, '2017-04-17 15:00:00', '2017-04-17 15:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#509', '2017-1', 'Exercícios de Desafio 3: Estruturas Encadeadas', 'Introdução à Programação de Computadores', 135, '2017-04-19 16:00:00', '2017-05-08 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 6
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#632', '2017-1', 'Laboratório de Codificação 05 – Vetores e Strings', 'Introdução à Programação de Computadores', 135, '2017-05-22 16:00:00', '2017-06-02 23:00:00', 'Python 3', 'python/python.js', 'homework', 1, 11
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#468', '2017-1', 'Trabalho Prático 01: Variáveis e Estrutura Sequencial de Programação', 'Introdução à Programação de Computadores', 135, '2017-04-04 10:00:00', '2017-04-04 10:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#477', '2017-1', 'Exercícios de Desafio 2: Estruturas Condicionais Simples e Compostas', 'Introdução à Programação de Computadores', 135, '2017-04-05 16:00:00', '2017-04-19 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 6
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#729', '2017-1', 'Laboratório de Codificação 07 – Matrizes', 'Introdução à Programação de Computadores', 135, '2017-06-21 00:00:00', '2017-07-12 23:59:00', 'Python 3', 'python/python.js', 'homework', 1, 10
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#454', '2017-1', 'Laboratório de Codificação 01 – Variáveis e Estrutura Sequencial de Programação', 'Introdução à Programação de Computadores', 135, '2017-03-20 00:00:00', '2017-04-03 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#711', '2017-1', 'Trabalho Prático 6: Repetição por Contagem', 'Introdução à Programação de Computadores', 135, '2017-06-19 14:00:00', '2017-06-19 14:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#584', '2017-1', 'Laboratório de Codificação 04 – Estrutura de Programação de Repetição por Condição', 'Introdução à Programação de Computadores', 135, '2017-05-08 16:00:00', '2017-05-17 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 12
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#663', '2017-1', 'Trabalho Prático 5: Vetores e Strings', 'Introdução à Programação de Computadores', 135, '2017-05-31 15:00:00', '2017-05-31 15:55:00', 'Python 3', 'python/python.js', 'exam', 1, 2
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#649', '2017-1', 'Exercícios de Desafio 5: Vetores e Strings', 'Introdução à Programação de Computadores', 135, '2017-05-25 00:00:00', '2017-06-05 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 5
# semester_id=2017-1, class_id=135, assessment_id=assessment_id, semester_id, assessment_title, class_name, class_number, start, end, language, codemirror_mode, type, weight, total_exercises, feature_value='2017-1#135#495', '2017-1', 'Laboratório de Codificação 02 – Estrutura de Programação Condicional', 'Introdução à Programação de Computadores', 135, '2017-04-05 16:00:00', '2017-04-17 14:00:00', 'Python 3', 'python/python.js', 'homework', 1, 9
