# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_preditions/df1_all_preditions.csv')
df2 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_preditions/df2_all_preditions.csv')
df3 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_preditions/df3_all_preditions.csv')
df4 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_preditions/df4_all_preditions.csv')
df5 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_preditions/df5_all_preditions.csv')
df6 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_preditions/df6_all_preditions.csv')

# %%
df1
# Out:
#             target   status  ...  prediction_xgb  prediction_gnb
# 0       Desistente    Ativo  ...      Desistente      Desistente
# 1       Desistente    Ativo  ...      Desistente      Desistente
# 2   Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 3       Desistente    Ativo  ...      Desistente      Desistente
# 4       Desistente    Ativo  ...      Desistente      Desistente
# 5   Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 6   Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 7   Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 8   Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 9   Não Desistente    Ativo  ...  Não Desistente      Desistente
# 10  Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 11  Não Desistente    Ativo  ...  Não Desistente  Não Desistente
# 12      Desistente  Inativo  ...      Desistente      Desistente
# ...

# %%
df_rf_prediction = pd.DataFrame()
df_rf_prediction['classe'] = df1['target']
df_rf_prediction['exam_1'] = df1['prediction_rf']
df_rf_prediction['exam_2'] = df2['prediction_rf']
df_rf_prediction['exam_3'] = df3['prediction_rf']
df_rf_prediction['exam_4'] = df4['prediction_rf']
df_rf_prediction['exam_5'] = df5['prediction_rf']
df_rf_prediction['exam_6'] = df6['prediction_rf']
df_rf_prediction
# Out:
#             classe          exam_1  ...          exam_5          exam_6
# 0       Desistente      Desistente  ...      Desistente      Desistente
# 1       Desistente      Desistente  ...      Desistente      Desistente
# 2   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 3       Desistente      Desistente  ...      Desistente      Desistente
# 4       Desistente      Desistente  ...      Desistente      Desistente
# 5   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 6   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 7   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 8   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 9   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 10  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 11  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# ...

# %%
df_etc_prediction = pd.DataFrame()
df_etc_prediction['classe'] = df1['target']
df_etc_prediction['exam_1'] = df1['prediction_etc']
df_etc_prediction['exam_2'] = df2['prediction_etc']
df_etc_prediction['exam_3'] = df3['prediction_etc']
df_etc_prediction['exam_4'] = df4['prediction_etc']
df_etc_prediction['exam_5'] = df5['prediction_etc']
df_etc_prediction['exam_6'] = df6['prediction_etc']
df_etc_prediction
# Out:
#             classe          exam_1  ...          exam_5          exam_6
# 0       Desistente      Desistente  ...      Desistente      Desistente
# 1       Desistente      Desistente  ...      Desistente      Desistente
# 2   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 3       Desistente      Desistente  ...      Desistente      Desistente
# 4       Desistente      Desistente  ...      Desistente      Desistente
# 5   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 6   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 7   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 8   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 9   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 10  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 11  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# ...

# %%
df_xgb_prediction = pd.DataFrame()
df_xgb_prediction['classe'] = df1['target']
df_xgb_prediction['exam_1'] = df1['prediction_xgb']
df_xgb_prediction['exam_2'] = df2['prediction_xgb']
df_xgb_prediction['exam_3'] = df3['prediction_xgb']
df_xgb_prediction['exam_4'] = df4['prediction_xgb']
df_xgb_prediction['exam_5'] = df5['prediction_xgb']
df_xgb_prediction['exam_6'] = df6['prediction_xgb']
df_xgb_prediction
# Out:
#             classe          exam_1  ...          exam_5          exam_6
# 0       Desistente      Desistente  ...      Desistente      Desistente
# 1       Desistente      Desistente  ...  Não Desistente      Desistente
# 2   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 3       Desistente      Desistente  ...      Desistente      Desistente
# 4       Desistente      Desistente  ...      Desistente      Desistente
# 5   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 6   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 7   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 8   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 9   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 10  Não Desistente  Não Desistente  ...      Desistente  Não Desistente
# 11  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# ...

# %%
df_gnb_prediction = pd.DataFrame()
df_gnb_prediction['classe'] = df1['target']
df_gnb_prediction['exam_1'] = df1['prediction_gnb']
df_gnb_prediction['exam_2'] = df2['prediction_gnb']
df_gnb_prediction['exam_3'] = df3['prediction_gnb']
df_gnb_prediction['exam_4'] = df4['prediction_gnb']
df_gnb_prediction['exam_5'] = df5['prediction_gnb']
df_gnb_prediction['exam_6'] = df6['prediction_gnb']
df_gnb_prediction
# Out:
#             classe          exam_1  ...          exam_5          exam_6
# 0       Desistente      Desistente  ...      Desistente      Desistente
# 1       Desistente      Desistente  ...      Desistente      Desistente
# 2   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 3       Desistente      Desistente  ...      Desistente      Desistente
# 4       Desistente      Desistente  ...      Desistente      Desistente
# 5   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 6   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 7   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 8   Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 9   Não Desistente      Desistente  ...  Não Desistente  Não Desistente
# 10  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# 11  Não Desistente  Não Desistente  ...  Não Desistente  Não Desistente
# ...

# %%
df_rf_prediction.to_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/group_preditions/rf_preditions.csv', index=False)
df_etc_prediction.to_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/group_preditions/etc_preditions.csv', index=False)
df_xgb_prediction.to_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/group_preditions/xgb_preditions.csv', index=False)
df_gnb_prediction.to_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/group_preditions/gnb_preditions.csv', index=False)

# %%
from pandas import ExcelWriter

writer = ExcelWriter('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/train_with_D.xlsx')

df_rf_prediction.to_excel(writer, 'random_forest')
df_etc_prediction.to_excel(writer, 'extra_tree_classifier')
df_xgb_prediction.to_excel(writer, 'xgboost')
df_gnb_prediction.to_excel(writer, 'gaussian_naive_bayes')

writer.save()

# %%
df1 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_metrics/df1.csv')
df2 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_metrics/df2.csv')
df3 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_metrics/df3.csv')
df4 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_metrics/df4.csv')
df5 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_metrics/df5.csv')
df6 = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/all_metrics/df6.csv')

writer = ExcelWriter('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/metrics.xlsx')

df1.to_excel(writer, 'exam_1')
df2.to_excel(writer, 'exam_2')
df3.to_excel(writer, 'exam_3')
df4.to_excel(writer, 'exam_4')
df5.to_excel(writer, 'exam_5')
df6.to_excel(writer, 'exam_6')

writer.save()
