# %%
#@title
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

def show_features_student(student_index):
    df_student = df_1.iloc[student_index, 3:].to_frame()
    df_student.rename({student_index:'exam_1'}, inplace=True, axis=1)
    df_student['exam_2'] = df_2.iloc[student_index, 3:].values
    df_student['exam_3'] = df_3.iloc[student_index, 3:].values
    df_student['exam_4'] = df_4.iloc[student_index, 3:].values
    df_student['exam_5'] = df_5.iloc[student_index, 3:].values
    df_student['exam_6'] = df_6.iloc[student_index, 3:].values
    return df_student

def plot_features(df_student): 
    Cols = 5
    title = df_student.index
    Tot = df_student.shape[0]

    Rows = Tot // Cols 
    Rows += Tot % Cols

    Position = range(1,Tot + 1)

    fig = plt.figure(1, figsize=(25, 45))
    for k in range(Tot):
        ax = fig.add_subplot(Rows,Cols,Position[k])
        ax.set_title(title[k])
        ax.plot(df_student.iloc[k])
    plt.show()

#!unzip -q '/content/drive/Shared drives/iniciacao_cientifica_2019_2020/codebench.zip'

# %%
#@title

path = '/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/e1.1/treino_com_desistentes.xlsx'

df_rf1 = pd.read_excel(path, sheet_name='random_forest')
df_etc1 = pd.read_excel(path, sheet_name='extra_tree_classifier')
df_xgb_we1 = pd.read_excel(path, sheet_name='xgboost_com_early_stopping')
df_xgb_ne1 = pd.read_excel(path, sheet_name='xgboost_sem_early_stopping')
df_gnb1 = pd.read_excel(path, sheet_name='gaussian_naive_bayes')

df_rf1.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_etc1.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_xgb_we1.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_xgb_ne1.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_gnb1.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)

path = '/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_experimento/e1.1/treino_sem_desistentes.xlsx'
df_rf2 = pd.read_excel(path, sheet_name='random_forest')
df_etc2 = pd.read_excel(path, sheet_name='extra_tree_classifier')
df_xgb_we2 = pd.read_excel(path, sheet_name='xgboost_com_early_stopping')
df_xgb_ne2 = pd.read_excel(path, sheet_name='xgboost_sem_early_stopping')
df_gnb2 = pd.read_excel(path, sheet_name='gaussian_naive_bayes')

df_rf2.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_etc2.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_xgb_we2.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_xgb_ne2.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)
df_gnb2.rename({'Unnamed: 0':'student'}, inplace=True, axis=1)

path = '/content/drive/Shared drives/iniciacao_cientifica_2019_2020/dataframes_treino/turma_102_2016_1.1/treino.xlsx'
df_1 = pd.read_excel(path, sheet_name='exam_0')
df_2 = pd.read_excel(path, sheet_name='exam_1')
df_3 = pd.read_excel(path, sheet_name='exam_2')
df_4 = pd.read_excel(path, sheet_name='exam_3')
df_5 = pd.read_excel(path, sheet_name='exam_4')
df_6 = pd.read_excel(path, sheet_name='exam_5')

df_user_target = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/csv_datasets/usuarios_classificados.csv')
df_valid_assessment = pd.read_csv('/content/drive/Shared drives/iniciacao_cientifica_2019_2020/csv_datasets/avaliacoes_validas.csv', sep=';')

# %% [markdown]
# # Analises de alunos nos experimentos

# %% [markdown]
# **Experimento 1:** O primeiro experimento consistiu em treinar o modelo com todos os alunos da turma 102 do semestre 2016-1, cada treinamento foi feito com 6 conjuntos de dados, cada conjunto consiste de dados acumulados do inicio até a cada uma das provas.
#
# **Experimento 2:** O experimento dois usou a mesma turma com os mesmos dados, com uma pequena modificação, toda vez que um aluno era classificado como **Desistente** era retirado do conjunto e no próximo treinamento ele não fazia mais parte do conjunto
#
# - Foram usados 5 técnicas de Aprendizado de Máquina: Random Forest, Extra Tree Classifier, XGBoost com early_stopping e XGBoost sem early_stopping e Gaussian Naive Bayes
#
# Segue abaixo o resultado da classificação das técnicas empregadas.

# %% [markdown]
# ## Predições com dados acumulados até as respectivas avaliações

# %% [markdown]
# # Random forest predições **experimento 1**

# %%
#@title
df_rf1
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...      Desistente      Desistente
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...      Desistente      Desistente
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...      Desistente      Desistente
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...      Desistente      Desistente
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente      Desistente
# 24       24      Desistente  ...      Desistente      Desistente
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...      Desistente      Desistente
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...      Desistente      Desistente
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...      Desistente      Desistente
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...      Desistente      Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...      Desistente      Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...  Não Desistente  Não Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente      Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## Random Forest predições **Experimento 2**

# %%
#@title
df_rf2
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...             NaN             NaN
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...             NaN             NaN
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...             NaN             NaN
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...             NaN             NaN
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...             NaN             NaN
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...             NaN             NaN
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...             NaN             NaN
# 35       35  Não Desistente  ...             NaN             NaN
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...             NaN             NaN
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...  Não Desistente  Não Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...      Desistente             NaN
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...             NaN             NaN
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...             NaN             NaN
#
# [53 rows x 8 columns]

# %% [markdown]
# ## Extra Tree Classifier predições **Experimento 1**

# %%
#@title
df_etc1
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...      Desistente      Desistente
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...      Desistente      Desistente
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...      Desistente      Desistente
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...      Desistente      Desistente
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...      Desistente      Desistente
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...      Desistente      Desistente
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...      Desistente      Desistente
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...      Desistente      Desistente
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...      Desistente      Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...      Desistente      Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...  Não Desistente  Não Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente      Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## Extra Tree Classifier **Experimento 2**

# %%
#@title
df_etc2
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...             NaN             NaN
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...             NaN             NaN
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...             NaN             NaN
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...             NaN             NaN
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...             NaN             NaN
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...             NaN             NaN
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...             NaN             NaN
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...             NaN             NaN
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...  Não Desistente  Não Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...  Não Desistente  Não Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...  Não Desistente  Não Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente  Não Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## XGBoost com early_stopping **experimento 1**

# %%
#@title
df_xgb_we1
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...      Desistente      Desistente
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...      Desistente      Desistente
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...      Desistente      Desistente
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...      Desistente      Desistente
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...      Desistente      Desistente
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...      Desistente      Desistente
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...      Desistente      Desistente
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...      Desistente      Desistente
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...      Desistente      Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...      Desistente      Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...      Desistente      Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente  Não Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## XGBoost sem early_stopping **experimento 1**

# %%
#@title
df_xgb_ne1
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...      Desistente      Desistente
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...      Desistente      Desistente
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...      Desistente      Desistente
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...      Desistente      Desistente
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...      Desistente      Desistente
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...      Desistente      Desistente
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...      Desistente      Desistente
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...      Desistente      Desistente
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...      Desistente      Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...      Desistente      Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...      Desistente      Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente  Não Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## XGBoost com early_stopping **experimento 2**

# %%
#@title
df_xgb_we2
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...             NaN             NaN
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...             NaN             NaN
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...             NaN             NaN
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...             NaN             NaN
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...             NaN             NaN
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...             NaN             NaN
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...             NaN             NaN
# 33       33  Não Desistente  ...             NaN             NaN
# 34       34      Desistente  ...             NaN             NaN
# 35       35  Não Desistente  ...             NaN             NaN
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...             NaN             NaN
# 40       40  Não Desistente  ...             NaN             NaN
# 41       41      Desistente  ...  Não Desistente  Não Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...             NaN             NaN
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...             NaN             NaN
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...             NaN             NaN
#
# [53 rows x 8 columns]

# %% [markdown]
# ## XGBoost sem early_stopping **experimento 2**

# %%
#@title
df_xgb_ne2
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...             NaN             NaN
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...             NaN             NaN
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...             NaN             NaN
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...             NaN             NaN
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...             NaN             NaN
# 24       24      Desistente  ...             NaN             NaN
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...             NaN             NaN
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...             NaN             NaN
# 35       35  Não Desistente  ...             NaN             NaN
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...             NaN             NaN
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...      Desistente             NaN
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...  Não Desistente  Não Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...  Não Desistente  Não Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...             NaN             NaN
# 52       52  Não Desistente  ...             NaN             NaN
#
# [53 rows x 8 columns]

# %% [markdown]
# ## Gaussian Naive Bayes **experimento 1**

# %%
#@title
df_gnb1
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...      Desistente      Desistente
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...      Desistente      Desistente
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...      Desistente      Desistente
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...  Não Desistente  Não Desistente
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...      Desistente      Desistente
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...  Não Desistente  Não Desistente
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...      Desistente      Desistente
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...      Desistente      Desistente
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...  Não Desistente  Não Desistente
# 34       34      Desistente  ...      Desistente      Desistente
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...      Desistente      Desistente
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...      Desistente      Desistente
# 42       42  Não Desistente  ...  Não Desistente  Não Desistente
# 43       43      Desistente  ...  Não Desistente  Não Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...  Não Desistente  Não Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente  Não Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## Gaussian Naive Bayes **experimento 2**

# %%
#@title
df_gnb2
# Out:
#     student          target  ...          exam_5          exam_6
# 0         0      Desistente  ...             NaN             NaN
# 1         1  Não Desistente  ...  Não Desistente  Não Desistente
# 2         2      Desistente  ...             NaN             NaN
# 3         3  Não Desistente  ...  Não Desistente  Não Desistente
# 4         4      Desistente  ...             NaN             NaN
# 5         5  Não Desistente  ...  Não Desistente  Não Desistente
# 6         6  Não Desistente  ...             NaN             NaN
# 7         7  Não Desistente  ...  Não Desistente  Não Desistente
# 8         8  Não Desistente  ...  Não Desistente  Não Desistente
# 9         9  Não Desistente  ...  Não Desistente  Não Desistente
# 10       10  Não Desistente  ...  Não Desistente  Não Desistente
# 11       11  Não Desistente  ...  Não Desistente  Não Desistente
# 12       12  Não Desistente  ...  Não Desistente  Não Desistente
# 13       13  Não Desistente  ...  Não Desistente  Não Desistente
# 14       14  Não Desistente  ...  Não Desistente  Não Desistente
# 15       15  Não Desistente  ...  Não Desistente  Não Desistente
# 16       16  Não Desistente  ...  Não Desistente  Não Desistente
# 17       17  Não Desistente  ...  Não Desistente  Não Desistente
# 18       18      Desistente  ...             NaN             NaN
# 19       19  Não Desistente  ...  Não Desistente  Não Desistente
# 20       20  Não Desistente  ...  Não Desistente  Não Desistente
# 21       21  Não Desistente  ...             NaN             NaN
# 22       22  Não Desistente  ...  Não Desistente  Não Desistente
# 23       23  Não Desistente  ...  Não Desistente  Não Desistente
# 24       24      Desistente  ...             NaN             NaN
# 25       25  Não Desistente  ...  Não Desistente  Não Desistente
# 26       26  Não Desistente  ...  Não Desistente  Não Desistente
# 27       27  Não Desistente  ...  Não Desistente  Não Desistente
# 28       28      Desistente  ...             NaN             NaN
# 29       29  Não Desistente  ...  Não Desistente  Não Desistente
# 30       30  Não Desistente  ...  Não Desistente  Não Desistente
# 31       31  Não Desistente  ...  Não Desistente  Não Desistente
# 32       32  Não Desistente  ...  Não Desistente  Não Desistente
# 33       33  Não Desistente  ...             NaN             NaN
# 34       34      Desistente  ...             NaN             NaN
# 35       35  Não Desistente  ...  Não Desistente  Não Desistente
# 36       36  Não Desistente  ...  Não Desistente  Não Desistente
# 37       37  Não Desistente  ...  Não Desistente  Não Desistente
# 38       38  Não Desistente  ...  Não Desistente  Não Desistente
# 39       39      Desistente  ...             NaN             NaN
# 40       40  Não Desistente  ...  Não Desistente  Não Desistente
# 41       41      Desistente  ...             NaN             NaN
# 42       42  Não Desistente  ...             NaN             NaN
# 43       43      Desistente  ...  Não Desistente  Não Desistente
# 44       44  Não Desistente  ...  Não Desistente  Não Desistente
# 45       45  Não Desistente  ...  Não Desistente  Não Desistente
# 46       46  Não Desistente  ...  Não Desistente  Não Desistente
# 47       47  Não Desistente  ...  Não Desistente  Não Desistente
# 48       48      Desistente  ...  Não Desistente  Não Desistente
# 49       49  Não Desistente  ...  Não Desistente  Não Desistente
# 50       50  Não Desistente  ...  Não Desistente  Não Desistente
# 51       51  Não Desistente  ...  Não Desistente  Não Desistente
# 52       52  Não Desistente  ...  Não Desistente  Não Desistente
#
# [53 rows x 8 columns]

# %% [markdown]
# ## Os seguintes alunos tiveram comportamento incomum em algum experimento
#
# * 6
#
# * 7
#
# * 21
#
# * 23
#
# * 29
#
# * 34
#
# * 35
#
# * 38
#
# * 41
#
# * 42
#
# * 43
#
# * 46
#
# * 47
#
# * 48
#
# * 51
#
# * 52
#
# Será feita uma inspeção mais detalhad desses alunos.

# %% [markdown]
# ## Analisando os alunos com comportamentos extranhos nos experimentos

# %% [markdown]
# ## **Aluno 6**

# %%
#@title
student_6 = show_features_student(6)
student_6
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          9       25  ...       47       55
# average_active_time              539.333  1097.55  ...    724.5  561.586
# average_exam_sub_comp                0.5     0.75  ...      0.8   0.6667
# average_exam_sub_inc                   2      4.5  ...      4.3   3.6667
# average_exam_sub_err                   1        2  ...      2.2   2.8333
# average_exam_sub_mean_time         102.4   1359.1  ...  592.564  510.932
# average_exam_test                     16    13.25  ...     13.3  14.0833
# average_exam_test_err                  9        8  ...      5.4   7.4167
# average_exam_test_mean_time      25.3385  1900.83  ...  819.802  688.835
# average_exam_code_line               8.5       16  ...       14    13.75
# average_homework_sub_comp              1        1  ...        1        1
# average_homework_sub_inc          0.1429   0.6875  ...   0.4737   0.3793
# average_homework_sub_err               0    0.875  ...   0.8947   0.8276
# average_homework_sub_mean_time   27.7143  2640.09  ...  1176.84  883.008
# average_homework_test             0.1429   3.0625  ...   2.7105   1.8103
# average_homework_test_err              0   2.4375  ...   1.9474   1.3103
# average_homework_test_mean_time        0  6168.05  ...   2611.4  1710.92
# average_homework_code_line        9.8571  17.4375  ...  14.6842  14.6207
# sum_exam_sub_comp                      1        3  ...        8        8
# sum_exam_sub_inc                       4       18  ...       43       44
# sum_exam_sub_err                       2        8  ...       22       34
# sum_exam_sub_mean_time             204.8  5436.39  ...  5925.64  6131.19
# sum_exam_test                         32       53  ...      133      169
# sum_exam_test_err                     18       32  ...       54       89
# sum_exam_test_mean_time           50.677  7603.32  ...  8198.02  8266.02
# sum_exam_code_line                    17       64  ...      140      165
# sum_homework_sub_comp                  7       16  ...       38       58
# sum_homework_sub_inc                   1       11  ...       18       22
# sum_homework_sub_err                   0       14  ...       34       48
# sum_homework_sub_mean_time           194  42241.5  ...    44720  51214.5
# sum_homework_test                      1       49  ...      103      105
# sum_homework_test_err                  0       39  ...       74       76
# sum_homework_test_mean_time            0  98688.8  ...  99233.1  99233.1
# sum_homework_code_line                69      279  ...      558      848
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_6)

# %% [markdown]
# - O aluno apresenta com comportamento normal comparado com a turma em geral.
#
# - No inicio teve baixa atividade nas avaliações do tipo homework, seria esse o motivo dele ter sido classificado de forma errada pelo modelo Gaussian Naive Bayes no  experimento 1 e também no experimento 2?????

# %% [markdown]
# ## **Aluno 7**

# %%
#@title
student_7 = show_features_student(7)
student_7
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                         18       57  ...       83       83
# average_active_time              1661.89  3096.35  ...  2031.67  2031.67
# average_exam_sub_comp                0.5      0.5  ...   0.3333   0.3333
# average_exam_sub_inc                  17    13.75  ...      9.5      9.5
# average_exam_sub_err                   6        4  ...   2.8333   2.8333
# average_exam_sub_mean_time       42.5916  45.7708  ...  32.6805  32.6805
# average_exam_test                   60.5    42.75  ...       35       35
# average_exam_test_err               11.5      8.5  ...  10.8333  10.8333
# average_exam_test_mean_time       30.371  79.1912  ...  63.0662  63.0662
# average_exam_code_line               9.5       17  ...     14.5     14.5
# average_homework_sub_comp         1.1429   1.0625  ...   0.9118   0.9118
# average_homework_sub_inc          6.7143   13.125  ...   6.3235   6.3235
# average_homework_sub_err         14.2857       10  ...   4.9706   4.9706
# average_homework_sub_mean_time   353.913   2152.3  ...  1040.91  1040.91
# average_homework_test            37.4286    51.75  ...     29.5     29.5
# average_homework_test_err        22.1429  23.3125  ...  12.7647  12.7647
# average_homework_test_mean_time  249.185  1502.83  ...  1071.45  1071.45
# average_homework_code_line        8.8571  15.4375  ...  13.3824  13.3824
# sum_exam_sub_comp                      1        2  ...        2        2
# sum_exam_sub_inc                      34       55  ...       57       57
# sum_exam_sub_err                      12       16  ...       17       17
# sum_exam_sub_mean_time           85.1831  183.083  ...  196.083  196.083
# sum_exam_test                        121      171  ...      210      210
# sum_exam_test_err                     23       34  ...       65       65
# sum_exam_test_mean_time           60.742  316.765  ...  378.397  378.397
# sum_exam_code_line                    19       68  ...       87       87
# sum_homework_sub_comp                  8       17  ...       31       31
# sum_homework_sub_inc                  47      210  ...      215      215
# sum_homework_sub_err                 100      160  ...      169      169
# sum_homework_sub_mean_time       2477.39  34436.8  ...    35391    35391
# sum_homework_test                    262      828  ...     1003     1003
# sum_homework_test_err                155      373  ...      434      434
# sum_homework_test_mean_time      1744.29  24045.2  ...  36429.2  36429.2
# sum_homework_code_line                62      247  ...      455      455
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_7)

# %% [markdown]
# - A partir dos seus dados é possível observar que este aluno foi bem até a terceira prova, mas depois caiu o desempenho.
#
# - Ele apresentou problema com o modelo xgboost com early_stopping no experimento 1 com dados até a primeira prova, mas depois não teve mais problemas

# %% [markdown]
# ## **Aluno 21**

# %%
#@title
student_21 = show_features_student(21)
student_21
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          6       29  ...       95      130
# average_active_time              608.889  1186.15  ...   1155.6  1277.09
# average_exam_sub_comp                1.5     1.25  ...      1.3     1.25
# average_exam_sub_inc                 1.5      2.5  ...      1.9   2.1667
# average_exam_sub_err                 1.5      1.5  ...      0.7   0.9167
# average_exam_sub_mean_time       77.5834  96.7917  ...  1098.98  930.149
# average_exam_test                    3.5    10.75  ...     11.7    16.25
# average_exam_test_err                1.5     3.25  ...      1.9   5.8333
# average_exam_test_mean_time      42.0835  42.5798  ...  240.262  210.511
# average_exam_code_line                11     20.5  ...     16.6  16.1667
# average_homework_sub_comp              1   3.4375  ...   2.7632   2.3966
# average_homework_sub_inc          0.5714    1.625  ...   2.7632   3.4828
# average_homework_sub_err               0   3.6875  ...   3.5263   3.0517
# average_homework_sub_mean_time   193.333  2213.89  ...  3558.91  2812.16
# average_homework_test                  0    5.125  ...  10.9211       14
# average_homework_test_err              0   3.1875  ...   3.2368   5.1724
# average_homework_test_mean_time        0   1321.5  ...  3884.91  2700.97
# average_homework_code_line        7.7143  15.4375  ...  13.6579  14.0345
# sum_exam_sub_comp                      3        5  ...       13       15
# sum_exam_sub_inc                       3       10  ...       19       26
# sum_exam_sub_err                       3        6  ...        7       11
# sum_exam_sub_mean_time           155.167  387.167  ...  10989.8  11161.8
# sum_exam_test                          7       43  ...      117      195
# sum_exam_test_err                      3       13  ...       19       70
# sum_exam_test_mean_time           84.167  170.319  ...  2402.62  2526.13
# sum_exam_code_line                    22       82  ...      166      194
# sum_homework_sub_comp                  7       55  ...      105      139
# sum_homework_sub_inc                   4       26  ...      105      202
# sum_homework_sub_err                   0       59  ...      134      177
# sum_homework_sub_mean_time       1353.33  35422.2  ...   135238   163105
# sum_homework_test                      0       82  ...      415      812
# sum_homework_test_err                  0       51  ...      123      300
# sum_homework_test_mean_time            0    21144  ...   147627   156656
# sum_homework_code_line                54      247  ...      519      814
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_21)

# %% [markdown]
# - Apresenta comportamento similar ao aluno 6 e deve o mesmo problema de ser classificado nos dois experimentos como um aluno desistente com os dados da primeira prova.
#
# - A explicação para o erro do modelo foi uma baixa atividade na plataforma até a primeira prova?
#
# - Após a primeira prova ele tem mais atividades

# %% [markdown]
# ## Analisando o **aluno 23**

# %% [markdown]
# ### Dados do aluno 23 agrupados

# %%
#@title
df_student_23 = show_features_student(23)
df_student_23
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          6       14  ...       18       18
# average_active_time                 1317  1481.23  ...   1514.5   1514.5
# average_exam_sub_comp                  0     0.25  ...      0.2      0.2
# average_exam_sub_inc                   0      0.5  ...      0.4      0.4
# average_exam_sub_err                   3     6.25  ...        5        5
# average_exam_sub_mean_time          70.9  1088.28  ...   870.62   870.62
# average_exam_test                   34.5    44.75  ...       40       40
# average_exam_test_err               26.5    39.75  ...       36       36
# average_exam_test_mean_time       18.934  247.973  ...  213.928  213.928
# average_exam_code_line               5.5     8.75  ...     11.2     11.2
# average_homework_sub_comp            1.4   1.4444  ...   1.4444   1.4444
# average_homework_sub_inc               0        1  ...        1        1
# average_homework_sub_err               0   0.6667  ...   0.6667   0.6667
# average_homework_sub_mean_time     514.8   324.88  ...   324.88   324.88
# average_homework_test                4.2   5.2222  ...   5.2222   5.2222
# average_homework_test_err              3   3.4444  ...   3.4444   3.4444
# average_homework_test_mean_time  36.4334  38.7354  ...  38.7354  38.7354
# average_homework_code_line           6.6   9.2222  ...   9.2222   9.2222
# sum_exam_sub_comp                      0        1  ...        1        1
# sum_exam_sub_inc                       0        2  ...        2        2
# sum_exam_sub_err                       6       25  ...       25       25
# sum_exam_sub_mean_time             141.8   4353.1  ...   4353.1   4353.1
# sum_exam_test                         69      179  ...      200      200
# sum_exam_test_err                     53      159  ...      180      180
# sum_exam_test_mean_time           37.868  991.891  ...  1069.64  1069.64
# sum_exam_code_line                    11       35  ...       56       56
# sum_homework_sub_comp                  7       13  ...       13       13
# sum_homework_sub_inc                   0        9  ...        9        9
# sum_homework_sub_err                   0        6  ...        6        6
# sum_homework_sub_mean_time          2574  2923.92  ...  2923.92  2923.92
# sum_homework_test                     21       47  ...       47       47
# sum_homework_test_err                 15       31  ...       31       31
# sum_homework_test_mean_time      182.167  348.619  ...  348.619  348.619
# sum_homework_code_line                33       83  ...       83       83
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(df_student_23)

# %% [markdown]
# - Um ponto que se destaca no aluno 23 é que a partir da 3 prova ele não fez mais nenhuma avaliação válida, **mas continuava a fazer login**, será que por isso ele foi classificado como **Desistente** quando o modelo foi treinado com os dados de usuários até a 5º avaliação?
#
# - Ele não faz avaliações válidas talvez ainda continue fazendo avaliações não válidas como o **Lab 0**.
#
# - Ao comparar os valores das features do usuário 23 com os dados da turma até 6º prova é possível notar uma grande diferença.
#
# - Será que o usuário 23 continuou nas aulas e foi um aluno repovado por nota? já que ele não tem registros de ter feito mais nenhuma questão das avaliações e por isso ele não é classificado como **Desistente**?

# %% [markdown]
# - Visualizando a nota final de desse aluno.

# %%
# !cat /content/codebench/2016-1/102/users/1302/grades/final_grade.data
# Out:
# 1.14

# %% [markdown]
# - Como a nota final de foi 1.14 de média é provável que este aluno tenha sido reprovado por nota.

# %% [markdown]
# 106
# 126
# 136
# 149
# 173
# 199
# 217
# 44
# 75
# 97

# %%
# !ls /content/codebench/2016-1/102/users/1302/executions
# Out:
# 106_1079.log  136_1135.log  18_797.log	  44_1015.log  75_1054.log
# 106_1099.log  149_1154.log  18_994.log	  44_587.log   75_1055.log
# 106_1100.log  149_1169.log  18_996.log	  44_588.log   75_1056.log
# 126_1109.log  173_1197.log  18_999.log	  44_820.log   75_602.log
# 126_1149.log  173_1209.log  199_1257.log  44_835.log   75_820.log
# 136_1132.log  18_1000.log   217_1288.log  59_1023.log  75_869.log
# 136_1133.log  18_1001.log   217_1305.log  59_1029.log  97_1084.log
# 136_1134.log  18_578.log    44_1014.log   75_1053.log  97_1094.log

# %% [markdown]
# - o aluno 23 fez 10 avalições das 13 válidas (**106, 126, 136, 149, 173, 199, 217, 44, 75, 97**)

# %% [markdown]
# ## **Aluno 29**

# %%
#@title
student_29 = show_features_student(29)
student_29
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          9       20  ...       52       58
# average_active_time              1024.22  1501.47  ...   1190.4  1015.85
# average_exam_sub_comp                  1        1  ...      0.7   0.6364
# average_exam_sub_inc                   4     2.25  ...      2.1   1.9091
# average_exam_sub_err                 2.5        2  ...      1.1        1
# average_exam_sub_mean_time       17.5416  38.3958  ...  45.3968  41.2698
# average_exam_test                   13.5     12.5  ...     11.1  10.4545
# average_exam_test_err                2.5     3.75  ...      3.3   3.1818
# average_exam_test_mean_time        19.46    75.92  ...  82.6271  112.812
# average_exam_code_line              10.5     17.5  ...     15.5  14.7273
# average_homework_sub_comp              1   1.1333  ...   1.0541   1.0392
# average_homework_sub_inc          2.5714      4.6  ...   1.9459    1.451
# average_homework_sub_err          1.1429        2  ...   0.8649   0.6471
# average_homework_sub_mean_time   32.8649  3142.84  ...  1284.28  962.848
# average_homework_test             0.7143   5.7333  ...   7.6216   7.2157
# average_homework_test_err         0.2857      2.8  ...   2.2162   2.0196
# average_homework_test_mean_time  33.0357  409.449  ...   2679.7  1951.01
# average_homework_code_line       11.1429     16.2  ...  13.5946  14.4706
# sum_exam_sub_comp                      2        4  ...        7        7
# sum_exam_sub_inc                       8        9  ...       21       21
# sum_exam_sub_err                       5        8  ...       11       11
# sum_exam_sub_mean_time           35.0833  153.583  ...  453.968  453.968
# sum_exam_test                         27       50  ...      111      115
# sum_exam_test_err                      5       15  ...       33       35
# sum_exam_test_mean_time            38.92   303.68  ...  826.271  1240.94
# sum_exam_code_line                    21       70  ...      155      162
# sum_homework_sub_comp                  7       17  ...       39       53
# sum_homework_sub_inc                  18       69  ...       72       74
# sum_homework_sub_err                   8       30  ...       32       33
# sum_homework_sub_mean_time       230.054  47142.6  ...  47518.2  49105.2
# sum_homework_test                      5       86  ...      282      368
# sum_homework_test_err                  2       42  ...       82      103
# sum_homework_test_mean_time       231.25  6141.73  ...    99149  99501.4
# sum_homework_code_line                78      243  ...      503      738
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_29)

# %% [markdown]
# - O aluno apresenta o mesmo problema do aluno 6 e aluno 21 é classificado pelo classificador Gaussian Naive Bayes como de Desistente com dados até a primeira prova, mas é um não Desistente.
#
# - Esse aluno teve uma grande queda de desenpenho a partir da segunda prova.
#
# - Um desempenho bem similar a média da turma nos dados da primeira prova.
#
# - nenhum outro classificador errou esse aluno.

# %% [markdown]
# ## Analisando o **aluno 32**

# %% [markdown]
# - O aluno 32 aprensenta comportamento anormal porque ele é classificado com **Desistente**, mas em todos os teste com o modelo Random Forest ele é predito como **Não Desistente**, primeiramente visualiza-se os arquivos dele de interação com a plataforma, mais especificamente os arquivos **logs** de **execução** de códigos, ou seja, **submissão** e **testes**.

# %%
# !ls /content/codebench/2016-1/102/users/1311/executions
# Out:
# 18_1000.log  18_999.log   44_587.log  44_842.log   75_1055.log	97_1083.log
# 18_1001.log  44_1014.log  44_588.log  59_1022.log  75_1056.log	97_1098.log
# 18_797.log   44_1015.log  44_820.log  59_1031.log  75_602.log
# 18_994.log   44_1016.log  44_825.log  75_1053.log  75_820.log
# 18_996.log   44_1017.log  44_835.log  75_1054.log  75_869.log

# %% [markdown]
# - Ao visualizar os arquivos percebe-se que ele possui arquivos de **sumbissão** dos **homeworks** válidos: **44, 75** e do **teste** válido: **97**, das **13** Avaliações ele fez apenas **3** por isso é considerado **Desistente**.
#
# - Um ponto a ser destacado é que as **3** avaliações feitas pelo usuário compõem o primeiro conjunto de dados de treino.
#
# - Pode ser considerar que depois do primeiro **exam** o aluno desistiu?
#
# - Mesmo feito apenas **3** avaliações porque os modelo em todos os testes considerou ele como **Não Desistente**?

# %% [markdown]
# #### Visualizando as notas do aluno nas avaliações

# %%
# !cat /content/codebench/2016-1/102/users/1311/grades/44.log
# Out:
# ---- grade (0-10): 10
# ---- number of exercises: 10
# ---- correct: 10
# ---- incorrect: 0
# ---- blank: 0

# %%
# !cat /content/codebench/2016-1/102/users/1311/grades/75.log
# Out:
# ---- grade (0-10): 10
# ---- number of exercises: 7
# ---- correct: 7
# ---- incorrect: 0
# ---- blank: 0

# %%
# !cat /content/codebench/2016-1/102/users/1311/grades/97.log
# Out:
# ---- grade (0-10): 5
# ---- number of exercises: 2
# ---- correct: 1
# ---- incorrect: 1
# ---- blank: 0

# %% [markdown]
# #### Comparando os dados de treinamento do aluno 32 no primeiro conjunto de dados, isto é, até aprimeira prova com os dados de outros alunos

# %%
df_1.iloc[32, 3:]
# Out:
# number_logins                            5
# average_active_time                   1021
# average_exam_sub_comp                  0.5
# average_exam_sub_inc                    13
# average_exam_sub_err                   3.5
# average_exam_sub_mean_time           96.76
# average_exam_test                       21
# average_exam_test_err                 11.5
# average_exam_test_mean_time        45.9825
# average_exam_code_line                  11
# average_homework_sub_comp           1.2857
# average_homework_sub_inc            4.7143
# average_homework_sub_err            3.2857
# average_homework_sub_mean_time     276.235
# average_homework_test               5.7143
# average_homework_test_err           4.2857
# average_homework_test_mean_time    14.9961
# average_homework_code_line          8.4286
# sum_exam_sub_comp                        1
# sum_exam_sub_inc                        26
# sum_exam_sub_err                         7
# sum_exam_sub_mean_time              193.52
# sum_exam_test                           42
# sum_exam_test_err                       23
# sum_exam_test_mean_time             91.965
# sum_exam_code_line                      22
# sum_homework_sub_comp                    9
# sum_homework_sub_inc                    33
# sum_homework_sub_err                    23
# sum_homework_sub_mean_time         1933.64
# sum_homework_test                       40
# sum_homework_test_err                   30
# sum_homework_test_mean_time        104.973
# sum_homework_code_line                  59
# Name: 32, dtype: object

# %%
df_1.iloc[: , 3:].describe()
# Out:
#        number_logins  ...  sum_homework_code_line
# count      53.000000  ...               53.000000
# mean        7.094340  ...               51.075472
# std         3.628224  ...               23.468349
# min         0.000000  ...                0.000000
# 25%         5.000000  ...               54.000000
# 50%         7.000000  ...               59.000000
# 75%         9.000000  ...               64.000000
# max        18.000000  ...               83.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# - Os valores dos atributos do aluno 32 até primeria prova estão bem similares aos demais alunos, alguns ficam a cima da média da turma inclusive.
#
# - O aluno era bem ativo até a primeira prova.
#
# - Depois da primeira prova ele não teve mais atividade na plataforma.
#
# - Ele tirou nota máxima no **homework 44** e **75**, na prova 50% no **exam 97**

# %% [markdown]
# #### Visualizando os dados do aluno 32 nos demais conjuntos de treinamento

# %%
#@title
df_student_32 = df_1.iloc[32, 3:].to_frame()
df_student_32.rename({32:'exam_1'}, inplace=True, axis=1)
df_student_32['exam_2'] = df_2.iloc[32, 3:].values
df_student_32['exam_3'] = df_3.iloc[32, 3:].values
df_student_32['exam_4'] = df_4.iloc[32, 3:].values
df_student_32['exam_5'] = df_5.iloc[32, 3:].values
df_student_32['exam_6'] = df_6.iloc[32, 3:].values
df_student_32
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          5       17  ...       42       57
# average_active_time                 1021  1150.27  ...  705.452  666.809
# average_exam_sub_comp                0.5     2.25  ...   1.2222   1.0909
# average_exam_sub_inc                  13     32.5  ...  15.4444  12.8182
# average_exam_sub_err                 3.5        4  ...   2.2222        2
# average_exam_sub_mean_time         96.76  3586.23  ...  1661.74  1599.97
# average_exam_test                     21     56.5  ...  30.1111  26.6364
# average_exam_test_err               11.5     35.5  ...  20.2222  17.9091
# average_exam_test_mean_time      45.9825  997.548  ...  575.864  503.203
# average_exam_code_line                11       18  ...  12.1111  12.8182
# average_homework_sub_comp         1.2857   1.0909  ...   1.0303        1
# average_homework_sub_inc          4.7143   3.0909  ...   1.4848   1.3077
# average_homework_sub_err          3.2857   2.2727  ...   1.0303   1.6346
# average_homework_sub_mean_time   276.235  7679.79  ...  2812.06  1803.05
# average_homework_test             5.7143   4.9091  ...   4.5758   3.8269
# average_homework_test_err         4.2857   3.1818  ...   2.7273   2.2692
# average_homework_test_mean_time  14.9961  659.769  ...  291.969  219.806
# average_homework_code_line        8.4286  10.2727  ...  11.3939  12.7115
# sum_exam_sub_comp                      1        9  ...       11       12
# sum_exam_sub_inc                      26      130  ...      139      141
# sum_exam_sub_err                       7       16  ...       20       22
# sum_exam_sub_mean_time            193.52  14344.9  ...  14955.7  17599.7
# sum_exam_test                         42      226  ...      271      293
# sum_exam_test_err                     23      142  ...      182      197
# sum_exam_test_mean_time           91.965  3990.19  ...  5182.77  5535.23
# sum_exam_code_line                    22       72  ...      109      141
# sum_homework_sub_comp                  9       12  ...       34       52
# sum_homework_sub_inc                  33       34  ...       49       68
# sum_homework_sub_err                  23       25  ...       34       85
# sum_homework_sub_mean_time       1933.64  84477.6  ...  92797.9  93758.7
# sum_homework_test                     40       54  ...      151      199
# sum_homework_test_err                 30       35  ...       90      118
# sum_homework_test_mean_time      104.973  7257.46  ...  9634.97  11429.9
# sum_homework_code_line                59      113  ...      376      661
#
# [34 rows x 6 columns]

# %% [markdown]
# ## Analisando o mais detalhadamente o **aluno 33**

# %%
#@title
student_33 = show_features_student(33)
student_33
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                         12       30  ...       71       90
# average_active_time              1117.89   1247.4  ...  927.479  778.471
# average_exam_sub_comp                1.5      1.5  ...      1.1   0.9167
# average_exam_sub_inc                 3.5      3.5  ...      1.5     1.25
# average_exam_sub_err                   1      3.5  ...        2     1.75
# average_exam_sub_mean_time       812.214  471.637  ...  7309.45  6091.21
# average_exam_test                    9.5     16.5  ...      9.1   8.5833
# average_exam_test_err                1.5    10.75  ...      5.6   5.6667
# average_exam_test_mean_time      415.584   264.16  ...  9385.61  7829.61
# average_exam_code_line               9.5    11.75  ...       11  10.8333
# average_homework_sub_comp         1.4286   1.1875  ...   1.4474   1.3448
# average_homework_sub_inc          1.2857    1.625  ...   0.8684   0.7586
# average_homework_sub_err          0.2857        1  ...   1.3684   1.6379
# average_homework_sub_mean_time   1315.86  852.064  ...  773.383  2046.23
# average_homework_test             3.2857     5.75  ...   4.8158   3.9828
# average_homework_test_err         1.2857   3.3125  ...   2.5526   2.1552
# average_homework_test_mean_time  1166.41  531.892  ...   386.04  291.442
# average_homework_code_line        9.2857  14.0625  ...  13.3158  13.6034
# sum_exam_sub_comp                      3        6  ...       11       11
# sum_exam_sub_inc                       7       14  ...       15       15
# sum_exam_sub_err                       2       14  ...       20       21
# sum_exam_sub_mean_time           1624.43  1886.55  ...  73094.5  73094.5
# sum_exam_test                         19       66  ...       91      103
# sum_exam_test_err                      3       43  ...       56       68
# sum_exam_test_mean_time          831.167  1056.64  ...  93856.1  93955.4
# sum_exam_code_line                    19       47  ...      110      130
# sum_homework_sub_comp                 10       19  ...       55       78
# sum_homework_sub_inc                   9       26  ...       33       44
# sum_homework_sub_err                   2       16  ...       52       95
# sum_homework_sub_mean_time       9211.05    13633  ...  29388.6   118681
# sum_homework_test                     23       92  ...      183      231
# sum_homework_test_err                  9       53  ...       97      125
# sum_homework_test_mean_time      8164.87  8510.27  ...  14669.5  16903.6
# sum_homework_code_line                65      225  ...      506      789
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_33)

# %% [markdown]
# - É possível perceber que o **aluno 33** depois do segundo **exam** não teve mais atividade nas avaliações monitoradas é bem parecido com o aluno 32, começa bem mas para em um determinado tempo, no esperimento o modelo classificou ele com não desistente depois da terceira avaliação, o que foi o inverso do esperado já que foi depois da segunda avaliação que ele deixou de ser ativo

# %%
df_3.iloc[:, 3:].describe()
# Out:
#        number_logins  ...  sum_homework_code_line
# count      53.000000  ...               53.000000
# mean       27.641509  ...              174.132075
# std        15.664873  ...              100.284219
# min         0.000000  ...                0.000000
# 25%        18.000000  ...               85.000000
# 50%        29.000000  ...              225.000000
# 75%        36.000000  ...              252.000000
# max        74.000000  ...              309.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# - É possível perceber que a atividade dele até a 3º prova era baixa, mas não se diferenciava muito da média da turma

# %% [markdown]
# ### Visualizando os arquivos de nota no **aluno 33**

# %%
# !ls /content/codebench/2016-1/102/users/1312/grades/
# Out:
# 106.log  18.log  44.log  59.log  75.log  97.log  final_grade.data

# %% [markdown]
# - Ele possui os arquivos de nota de 3 **homeworks** válidos (44, 75, 106) e 1 **exam** válido (97).

# %%
# !cat /content/codebench/2016-1/102/users/1312/grades/44.log
# Out:
# ---- grade (0-10): 10
# ---- number of exercises: 10
# ---- correct: 10
# ---- incorrect: 0
# ---- blank: 0

# %% [markdown]
# - No primeiro exercício válido ele tirou nota máxima ou seja 10

# %%
# !cat /content/codebench/2016-1/102/users/1312/grades/75.log
# Out:
# ---- grade (0-10): 7.85714
# ---- number of exercises: 7
# ---- correct: 6
# ---- incorrect: 1
# ---- blank: 0

# %% [markdown]
# - No exercício 75 a nota já foi mais baixa

# %%
# !cat /content/codebench/2016-1/102/users/1312/grades/97.log
# Out:
# ---- grade (0-10): 5
# ---- number of exercises: 2
# ---- correct: 1
# ---- incorrect: 0
# ---- blank: 1

# %% [markdown]
# - Fez apenas 1 questão na primeira prova

# %%
# !cat /content/codebench/2016-1/102/users/1312/grades/106.log
# Out:
# ---- grade (0-10): 1.11111
# ---- number of exercises: 9
# ---- correct: 1
# ---- incorrect: 0
# ---- blank: 8

# %% [markdown]
# - No exercío depois da prova esse aluno foi bem ruim, fez apenas 1 questão e deixou as outras em branco

# %% [markdown]
# ## **Aluno 34**

# %%
#@title
student_34 = show_features_student(34)
student_34.fillna(0, inplace=True)
student_34
# Out:
#                                    exam_1    exam_2  ...    exam_5   exam_6
# number_logins                       3.000    20.000  ...    35.000   42.000
# average_active_time              1076.500  1076.500  ...  1076.500  575.000
# average_exam_sub_comp               0.000     0.000  ...     0.000    0.000
# average_exam_sub_inc                0.000     0.000  ...     0.000    0.000
# average_exam_sub_err                0.000     0.000  ...     0.000    0.000
# average_exam_sub_mean_time          0.000     0.000  ...     0.000    0.000
# average_exam_test                   0.000     0.000  ...     0.000    0.000
# average_exam_test_err               0.000     0.000  ...     0.000    0.000
# average_exam_test_mean_time         0.000     0.000  ...     0.000    0.000
# average_exam_code_line              0.000     0.000  ...     0.000    0.000
# average_homework_sub_comp           0.000     0.000  ...     0.000    0.000
# average_homework_sub_inc            2.500     2.500  ...     2.500    1.250
# average_homework_sub_err            1.000     1.000  ...     1.000    0.500
# average_homework_sub_mean_time    143.000   143.000  ...   143.000   71.500
# average_homework_test               8.500     8.500  ...     8.500    4.250
# average_homework_test_err           5.500     5.500  ...     5.500    2.750
# average_homework_test_mean_time   250.042   250.042  ...   250.042  125.021
# average_homework_code_line          9.000     9.000  ...     9.000   40.750
# sum_exam_sub_comp                   0.000     0.000  ...     0.000    0.000
# sum_exam_sub_inc                    0.000     0.000  ...     0.000    0.000
# sum_exam_sub_err                    0.000     0.000  ...     0.000    0.000
# sum_exam_sub_mean_time              0.000     0.000  ...     0.000    0.000
# sum_exam_test                       0.000     0.000  ...     0.000    0.000
# sum_exam_test_err                   0.000     0.000  ...     0.000    0.000
# sum_exam_test_mean_time             0.000     0.000  ...     0.000    0.000
# sum_exam_code_line                  0.000     0.000  ...     0.000    0.000
# sum_homework_sub_comp               0.000     0.000  ...     0.000    0.000
# sum_homework_sub_inc                5.000     5.000  ...     5.000    5.000
# sum_homework_sub_err                2.000     2.000  ...     2.000    2.000
# sum_homework_sub_mean_time        286.000   286.000  ...   286.000  286.000
# sum_homework_test                  17.000    17.000  ...    17.000   17.000
# sum_homework_test_err              11.000    11.000  ...    11.000   11.000
# sum_homework_test_mean_time       500.084   500.084  ...   500.084  500.084
# sum_homework_code_line             18.000    18.000  ...    18.000  163.000
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_34)

# %% [markdown]
# - O aluno é um Desistente, com algumas variáveis valor elevado, e com um pequena atividade no final.
#
# - Os gráficos Demontram que o usuário as vezes tinha atividade na plataforma, mais precisamente no final e no inicio.
#
# - O único modelo com problemas de classificar esse aluno foi o Extra Tree Classifier no experimento.

# %% [markdown]
# ## **Aluno 35**

# %% [markdown]
# - No segundo experimento os classificadores: Random Forest, XGBoost com e sem early_stopping apresentaram problemas para classificar esse aluno.
#
# - Os modelos classificaram ele como Sendo Desistente, mas ele é um Não Desistente

# %%
#@title
student_35 = show_features_student(35)
student_35
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          3       13  ...       46       56
# average_active_time              828.889  751.077  ...  395.615  334.724
# average_exam_sub_comp                0.5     0.25  ...     0.25     0.25
# average_exam_sub_inc                  11     7.75  ...    6.125    6.125
# average_exam_sub_err                 2.5        3  ...      2.5      2.5
# average_exam_sub_mean_time       130.821  119.377  ...  153.379  153.379
# average_exam_test                     26       30  ...   22.625   22.625
# average_exam_test_err               15.5    17.75  ...   13.375   13.375
# average_exam_test_mean_time      65.6065   44.388  ...  33.9834  33.9834
# average_exam_code_line               8.5      6.5  ...    5.875    5.875
# average_homework_sub_comp         1.1429   0.8889  ...   1.0323        1
# average_homework_sub_inc          0.8571   0.6667  ...   0.3226      0.3
# average_homework_sub_err               2   1.6667  ...   0.5161     1.18
# average_homework_sub_mean_time   47.0659  36.6068  ...  3815.27  2584.09
# average_homework_test             3.7143   4.5556  ...   1.5484     1.42
# average_homework_test_err         3.5714   4.4444  ...   1.2903     1.14
# average_homework_test_mean_time  23.3636  39.7744  ...  1815.19  1277.39
# average_homework_code_line        7.2857   8.7778  ...  11.5161    12.86
# sum_exam_sub_comp                      1        1  ...        2        2
# sum_exam_sub_inc                      22       31  ...       49       49
# sum_exam_sub_err                       5       12  ...       20       20
# sum_exam_sub_mean_time           261.643   477.51  ...  1227.03  1227.03
# sum_exam_test                         52      120  ...      181      181
# sum_exam_test_err                     31       71  ...      107      107
# sum_exam_test_mean_time          131.213  177.552  ...  271.867  271.867
# sum_exam_code_line                    17       26  ...       47       47
# sum_homework_sub_comp                  8        8  ...       32       50
# sum_homework_sub_inc                   6        6  ...       10       15
# sum_homework_sub_err                  14       15  ...       16       59
# sum_homework_sub_mean_time       329.462  329.462  ...   118273   129204
# sum_homework_test                     26       41  ...       48       71
# sum_homework_test_err                 25       40  ...       40       57
# sum_homework_test_mean_time      163.545   357.97  ...    56271  63869.7
# sum_homework_code_line                51       79  ...      357      643
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_35)

# %% [markdown]
# - Maioria da médias do aluno decaem a partir da segunda prova e é exatamente nesse ponto que começam a classificá-lo como Desistente, talvez isso indique uma relação com a classificação desses modelos, isto é se a atividade do usuário diminui consideravelmente como é o caso esses modelos tendem a classificar como Desistente.

# %% [markdown]
# ## **Aluno 38**

# %%
#@title
student_38 = show_features_student(38)
student_38
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          5       15  ...       30       36
# average_active_time              1046.56   1025.3  ...  839.465  608.631
# average_exam_sub_comp                1.5     1.25  ...      1.1   0.9167
# average_exam_sub_inc                   0        0  ...      0.6      0.5
# average_exam_sub_err                   0     1.75  ...      1.2   1.0833
# average_exam_sub_mean_time          6.75  163.661  ...  299.707  249.756
# average_exam_test                   31.5    21.25  ...     12.7  10.6667
# average_exam_test_err                  1     5.25  ...      4.1      3.5
# average_exam_test_mean_time      29.7915  131.646  ...  180.704  150.587
# average_exam_code_line                 9    10.75  ...     11.9    12.25
# average_homework_sub_comp         1.1429    0.875  ...   0.9394   0.9623
# average_homework_sub_inc          1.5714   1.1875  ...        1   0.6604
# average_homework_sub_err          1.1429   0.6875  ...   0.5152   0.3774
# average_homework_sub_mean_time   68.9683  65.3194  ...  49.4291   292.89
# average_homework_test             3.8571   3.4375  ...   4.9091   3.0755
# average_homework_test_err         1.7143    1.625  ...   1.9394   1.2264
# average_homework_test_mean_time  17.1169  22.3105  ...  33.5906  20.9149
# average_homework_code_line       10.1429   15.625  ...   13.697  13.9057
# sum_exam_sub_comp                      3        5  ...       11       11
# sum_exam_sub_inc                       0        0  ...        6        6
# sum_exam_sub_err                       0        7  ...       12       13
# sum_exam_sub_mean_time              13.5  654.643  ...  2997.07  2997.07
# sum_exam_test                         63       85  ...      127      128
# sum_exam_test_err                      2       21  ...       41       42
# sum_exam_test_mean_time           59.583  526.583  ...  1807.04  1807.04
# sum_exam_code_line                    18       43  ...      119      147
# sum_homework_sub_comp                  8       14  ...       31       51
# sum_homework_sub_inc                  11       19  ...       33       35
# sum_homework_sub_err                   8       11  ...       17       20
# sum_homework_sub_mean_time       482.778  1045.11  ...  1631.16  15523.2
# sum_homework_test                     27       55  ...      162      163
# sum_homework_test_err                 12       26  ...       64       65
# sum_homework_test_mean_time      119.818  356.968  ...  1108.49  1108.49
# sum_homework_code_line                71      250  ...      452      737
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_38)

# %% [markdown]
# - Algumas váriaveis estão zeradas na primeira e segunda prova, mas essas váriaveis podem não ser cruciais para identificar a atividade.
#
# - Mas para o Modelo Gaussian naive bayes isso pesa muito, como já foi identificado em outros alunos.
#
# - Parece que quanto mais baixo o valor das váriaveis ou maior a quantidade de zeros esse modelo tende a classificar como Desistente.

# %% [markdown]
# ## Analisando o **aluno 41**

# %% [markdown]
# - Comportamento desse aluno é no mínimo curioso.
#
# - No modelo Gaussian Naive Bayes ele foi classificado errado até a segunda prova, mas depois foi classificado de modo certo no Experimento 1.
#
# - Já nos modelos que usam árvore ele foi classificado errado com todos os datasets de treinamento até a 3º prova e depois acertam no experimento 1.
#
# - No esperimento 2 também se comportam parecido erram no inicio ou em todos os datasets.

# %%
#@title
student_41 = show_features_student(41)
student_41
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          4        6  ...        6        6
# average_active_time              1351.89   1522.8  ...   1522.8   1522.8
# average_exam_sub_comp                0.5      0.5  ...      0.5      0.5
# average_exam_sub_inc                   1        1  ...        1        1
# average_exam_sub_err                 0.5      0.5  ...      0.5      0.5
# average_exam_sub_mean_time            45       45  ...       45       45
# average_exam_test                     17       17  ...       17       17
# average_exam_test_err                7.5      7.5  ...      7.5      7.5
# average_exam_test_mean_time      40.7625  40.7625  ...  40.7625  40.7625
# average_exam_code_line                11       11  ...       11       11
# average_homework_sub_comp         0.8571    0.875  ...    0.875    0.875
# average_homework_sub_inc          1.1429        1  ...        1        1
# average_homework_sub_err          0.8571     0.75  ...     0.75     0.75
# average_homework_sub_mean_time    45.498  39.8107  ...  39.8107  39.8107
# average_homework_test                 13     14.5  ...     14.5     14.5
# average_homework_test_err         8.1429   10.125  ...   10.125   10.125
# average_homework_test_mean_time  31.6837  41.0097  ...  41.0097  41.0097
# average_homework_code_line        9.4286   10.625  ...   10.625   10.625
# sum_exam_sub_comp                      1        1  ...        1        1
# sum_exam_sub_inc                       2        2  ...        2        2
# sum_exam_sub_err                       1        1  ...        1        1
# sum_exam_sub_mean_time                90       90  ...       90       90
# sum_exam_test                         34       34  ...       34       34
# sum_exam_test_err                     15       15  ...       15       15
# sum_exam_test_mean_time           81.525   81.525  ...   81.525   81.525
# sum_exam_code_line                    22       22  ...       22       22
# sum_homework_sub_comp                  6        7  ...        7        7
# sum_homework_sub_inc                   8        8  ...        8        8
# sum_homework_sub_err                   6        6  ...        6        6
# sum_homework_sub_mean_time       318.486  318.486  ...  318.486  318.486
# sum_homework_test                     91      116  ...      116      116
# sum_homework_test_err                 57       81  ...       81       81
# sum_homework_test_mean_time      221.786  328.078  ...  328.078  328.078
# sum_homework_code_line                66       85  ...       85       85
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_41)

# %% [markdown]
# - Os dados desse usuário demonstram que até a segunda avaliação o aluno tinha atividade e alta inclusive, mas depois não deve mais.
#
# - Algumas variáveis aumentam muito pouco, isso influência????

# %% [markdown]
# ## **Aluno 43**

# %%
#@title
student_43 = show_features_student(43)
student_43
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                         10       14  ...       15       15
# average_active_time                967.2    967.2  ...    967.2    967.2
# average_exam_sub_comp                0.5      0.5  ...      0.5      0.5
# average_exam_sub_inc                 0.5      0.5  ...      0.5      0.5
# average_exam_sub_err                 0.5      0.5  ...      0.5      0.5
# average_exam_sub_mean_time           221      221  ...      221      221
# average_exam_test                     14       14  ...       14       14
# average_exam_test_err                2.5      2.5  ...      2.5      2.5
# average_exam_test_mean_time      81.2875  81.2875  ...  81.2875  81.2875
# average_exam_code_line                 7        7  ...        7        7
# average_homework_sub_comp              1        1  ...        1        1
# average_homework_sub_inc          0.6667   0.6667  ...   0.6667   0.6667
# average_homework_sub_err               0        0  ...        0        0
# average_homework_sub_mean_time   20.6667  20.6667  ...  20.6667  20.6667
# average_homework_test                  8        8  ...        8        8
# average_homework_test_err         2.6667   2.6667  ...   2.6667   2.6667
# average_homework_test_mean_time   48.185   48.185  ...   48.185   48.185
# average_homework_code_line        7.3333   7.3333  ...   7.3333   7.3333
# sum_exam_sub_comp                      1        1  ...        1        1
# sum_exam_sub_inc                       1        1  ...        1        1
# sum_exam_sub_err                       1        1  ...        1        1
# sum_exam_sub_mean_time               442      442  ...      442      442
# sum_exam_test                         28       28  ...       28       28
# sum_exam_test_err                      5        5  ...        5        5
# sum_exam_test_mean_time          162.575  162.575  ...  162.575  162.575
# sum_exam_code_line                    14       14  ...       14       14
# sum_homework_sub_comp                  3        3  ...        3        3
# sum_homework_sub_inc                   2        2  ...        2        2
# sum_homework_sub_err                   0        0  ...        0        0
# sum_homework_sub_mean_time            62       62  ...       62       62
# sum_homework_test                     24       24  ...       24       24
# sum_homework_test_err                  8        8  ...        8        8
# sum_homework_test_mean_time      144.555  144.555  ...  144.555  144.555
# sum_homework_code_line                22       22  ...       22       22
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_43)

# %% [markdown]
# - Usuário, não demonstra mais atividade considerável na plataforma depois da primeria prova, mas teve atividade considerável até a primeira atividade

# %% [markdown]
# ### **Aluno 48**

# %%
#@title
student_48 = show_features_student(48)
student_48
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          7        7  ...        8        8
# average_active_time              1217.22  1217.22  ...  1217.22  1217.22
# average_exam_sub_comp                0.5      0.5  ...      0.5      0.5
# average_exam_sub_inc                   7        7  ...        7        7
# average_exam_sub_err                   1        1  ...        1        1
# average_exam_sub_mean_time       33.3928  33.3928  ...  33.3928  33.3928
# average_exam_test                     12       12  ...       12       12
# average_exam_test_err                  8        8  ...        8        8
# average_exam_test_mean_time          326      326  ...      326      326
# average_exam_code_line               8.5      8.5  ...      8.5      8.5
# average_homework_sub_comp         1.1429   1.1429  ...   1.1429   1.1429
# average_homework_sub_inc          2.7143   2.7143  ...   2.7143   2.7143
# average_homework_sub_err          1.7143   1.7143  ...   1.7143   1.7143
# average_homework_sub_mean_time   1450.66  1450.66  ...  1450.66  1450.66
# average_homework_test                 10       10  ...       10       10
# average_homework_test_err         6.8571   6.8571  ...   6.8571   6.8571
# average_homework_test_mean_time  999.598  999.598  ...  999.598  999.598
# average_homework_code_line        9.4286   9.4286  ...   9.4286   9.4286
# sum_exam_sub_comp                      1        1  ...        1        1
# sum_exam_sub_inc                      14       14  ...       14       14
# sum_exam_sub_err                       2        2  ...        2        2
# sum_exam_sub_mean_time           66.7857  66.7857  ...  66.7857  66.7857
# sum_exam_test                         24       24  ...       24       24
# sum_exam_test_err                     16       16  ...       16       16
# sum_exam_test_mean_time              652      652  ...      652      652
# sum_exam_code_line                    17       17  ...       17       17
# sum_homework_sub_comp                  8        8  ...        8        8
# sum_homework_sub_inc                  19       19  ...       19       19
# sum_homework_sub_err                  12       12  ...       12       12
# sum_homework_sub_mean_time       10154.6  10154.6  ...  10154.6  10154.6
# sum_homework_test                     70       70  ...       70       70
# sum_homework_test_err                 48       48  ...       48       48
# sum_homework_test_mean_time      6997.18  6997.18  ...  6997.18  6997.18
# sum_homework_code_line                66       66  ...       66       66
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_48)

# %% [markdown]
# - É possível obsevar que o aluno 48 só fez as avaliações monitoradas até a primeira prova.
#
# - Também nota-se que tal aluno continuou a entrar na plataforma, talvez tenha tantado fazer outras avaliações diferentes daquelas monitoradas dentro da janela de tempo.

# %% [markdown]
# ## Analisando o **aluno 51**

# %%
#@title
student_51 = show_features_student(51)
student_51
# Out:
#                                   exam_1   exam_2  ...   exam_5   exam_6
# number_logins                          5       13  ...       65       95
# average_active_time              1364.89  1503.56  ...  1918.82   2139.7
# average_exam_sub_comp                0.5        1  ...      0.8   0.8333
# average_exam_sub_inc                 1.5     8.75  ...      3.8   3.5833
# average_exam_sub_err                   4     2.75  ...      1.2   1.0833
# average_exam_sub_mean_time       60.2272  67.7386  ...  125.295  112.865
# average_exam_test                      6      7.5  ...      9.5  13.1667
# average_exam_test_err                  6     3.75  ...        2   4.9167
# average_exam_test_mean_time      51.6365  27.3898  ...  248.495  227.577
# average_exam_code_line               7.5     12.5  ...     13.3       13
# average_homework_sub_comp         1.2857   1.1667  ...   1.8529   2.2222
# average_homework_sub_inc          3.1429   3.3333  ...   3.4118   2.7963
# average_homework_sub_err          4.7143   2.8333  ...   1.7059    1.963
# average_homework_sub_mean_time   45.3077  6912.99  ...  6232.87  10784.9
# average_homework_test             7.8571   8.6667  ...  18.0882       20
# average_homework_test_err         6.2857   4.8333  ...   5.6471      7.5
# average_homework_test_mean_time  21.5394   32.904  ...  3138.93   3352.7
# average_homework_code_line        7.7143  10.6667  ...  12.0588  12.7963
# sum_exam_sub_comp                      1        4  ...        8       10
# sum_exam_sub_inc                       3       35  ...       38       43
# sum_exam_sub_err                       8       11  ...       12       13
# sum_exam_sub_mean_time           120.454  270.954  ...  1252.95  1354.38
# sum_exam_test                         12       30  ...       95      158
# sum_exam_test_err                     12       15  ...       20       59
# sum_exam_test_mean_time          103.273  109.559  ...  2484.95  2730.93
# sum_exam_code_line                    15       50  ...      133      156
# sum_homework_sub_comp                  9       14  ...       63      120
# sum_homework_sub_inc                  22       40  ...      116      151
# sum_homework_sub_err                  33       34  ...       58      106
# sum_homework_sub_mean_time       317.154  82955.9  ...   211918   582383
# sum_homework_test                     55      104  ...      615     1080
# sum_homework_test_err                 44       58  ...      192      405
# sum_homework_test_mean_time      150.776  394.848  ...   106724   181046
# sum_homework_code_line                54      128  ...      410      691
#
# [34 rows x 6 columns]

# %%
#@title
plot_features(student_51)

# %% [markdown]
# ##### Visualizando as notas do aluno

# %%
# !cat /content/codebench/2016-1/102/users/1718/grades/*
# Out:
# ---- grade (0-10): 3.33333
# ---- number of exercises: 9
# ---- correct: 3
# ---- incorrect: 0
# ---- blank: 6---- grade (0-10): 5
# ---- number of exercises: 2
# ---- correct: 1
# ---- incorrect: 0
# ---- blank: 1---- grade (0-10): 0
# ---- number of exercises: 2
# ---- correct: 0
# ---- incorrect: 0
# ---- blank: 2---- grade (0-10): 2.85714
# ---- number of exercises: 7
# ---- correct: 2
# ---- incorrect: 1
# ---- blank: 4---- grade (0-10): 7.14286
# ---- number of exercises: 7
# ---- correct: 5
# ---- incorrect: 0
# ---- blank: 2---- grade (0-10): 0
# ---- number of exercises: 2
# ---- correct: 0
# ---- incorrect: 1
# ---- blank: 10.48

# %% [markdown]
# - Ao verficar a nota do aluno identifica-se que a sua maioria é bem baixa, chegando a ser zero em duas provas, e a sua média final sendo **0.48** levando em consideração as notas este aluno foi reprovado.

# %% [markdown]
# - O aluno não apresenta nenhuma interação nas avaliações monitoradas a partir da 3º avaliação.

# %% [markdown]
# ## Conclusão

# %% [markdown]
# - Nos modelos derivados de árvore de decisão, há um erro maior quando o usuário começa a fazer as tarefas e provas bem no inicio, mas depois param de fazer as provas e tarefas
#
#
# - Já no modelo de probabilidade há um também um maior erro quando o usuário começa bem e depois de um tempo ele não tem mais atividade. os alunos 51 e 36 no experimento 1 usando GNB apresentaram baixa taxa ou nenhuma de acertos em provas
