# %%
def extract_data_grade(path):
    features, values = [], []
    with open(path, 'r') as fl:
        for line in fl:
            data_grade = re.search(r'(\-{4}\s)(.+)(:\s)(.+)', line)
            if data_grade:
                feature = data_grade.group(2)
                value = data_grade.group(4)
                if 'grade' in feature:
                    feature = feature.split(' ')[0]
                feature = feature.replace(' of ', '_')
                features.append(feature)
                values.append(value)
    return features, values

# %%
import os
import re
import pymysql

from pprint import pprint
from datetime import datetime



def connection_database():
    connection = pymysql.connect(host='localhost',
                             user='root',
                             password='open',
                             db='dataset-workbench',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
    return connection

conn = connection_database()
cursor = conn.cursor()


cont = 0
for semester_id in os.listdir('../dataset/workbench/'):
    path0 = os.path.join('../dataset/workbench/', semester_id)
    for class_id in os.listdir(path0):
            path1 = os.path.join(path0, class_id)
            path2 = os.path.join(path1, 'users')
            for user_id in os.listdir(path2):
                    path3 = os.path.join(path2, user_id)
                    path4 = os.path.join(path3, 'grades')
                    for grade_id in os.listdir(path4):
                        if 'final' not in grade_id:
                            path5 = os.path.join(path4, grade_id)
                            features, values = extract_data_grade(path5)
                            grade_id = grade_id.replace('.log', '')
                            #print(f'semester_id={semester_id}, class_id={class_id}, user_id={user_id}, grade_id={grade_id}, features={features}, values={values}')
                            fk_user = f"'{semester_id}#{class_id}#{user_id}', "
                            fk_assessment = f"'{semester_id}#{class_id}#{grade_id}', "
                            features_ = 'user_id, assessment_id, '
                            values_ = fk_user + fk_assessment
                            for feature, value in zip(features, values):
                                features_ += f'{feature}, '
                                values_ += f'{value}, '
                                #print(fk_user, fk_assessment, feature, value)

                            insert_user_assessment_sql = f'INSERT INTO user_assessment ({features_[:-2]}) VALUES ({values_[:-2]})'
                            if cont < 1000:
                                print(insert_user_assessment_sql)
                                cont += 1
                            cursor.execute(insert_user_assessment_sql)
conn.commit()
conn.close()
# Out:
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1527', 0, 3, 0, 3, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1480', 3.33333, 12, 4, 2, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1375', 9.16667, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1505', 0, 3, 0, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1521', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1450', 9.16667, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1406', 0, 2, 0, 2, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1371', 5, 2, 1, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1451', 0, 12, 0, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1434', 1.1, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1510', 4.16667, 12, 5, 0, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3754', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1551', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1527', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1480', 5, 12, 6, 2, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1505', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1416', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1468', 3.33333, 3, 1, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1521', 7.5, 12, 9, 1, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1450', 5.83333, 12, 7, 1, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1325', 7.5, 12, 9, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1510', 5.83333, 12, 7, 1, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3798', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1551', 0, 3, 0, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1527', 0, 3, 0, 1, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1480', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1375', 9.16667, 12, 11, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1505', 1.1, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1468', 0, 3, 0, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1521', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1450', 9.16667, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1406', 5, 2, 1, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1371', 5, 2, 1, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1434', 2.23333, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1510', 1.66667, 12, 2, 1, 9)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3753', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3813', '2018-2#208#1375', 7.5, 12, 9, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3813', '2018-2#208#1406', 0, 2, 0, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3813', '2018-2#208#1371', 0, 2, 0, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3813', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3813', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3813', '2018-2#208#1415', 0, 12, 0, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1480', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1416', 2.5, 12, 3, 0, 9)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1521', 7.5, 12, 9, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1450', 6.66667, 12, 8, 0, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2535', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1375', 5.83333, 12, 7, 2, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1416', 0, 12, 0, 1, 11)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1371', 0, 2, 0, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1434', 0, 3, 0, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3741', '2018-2#208#1415', 3.33333, 12, 4, 1, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1375', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1468', 3.33333, 3, 1, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1450', 1.66667, 12, 2, 0, 10)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1406', 0, 2, 0, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1371', 5, 2, 1, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1325', 3.33333, 12, 4, 2, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3742', '2018-2#208#1415', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1551', 1.1, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1527', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1480', 9.725, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1375', 5.83333, 12, 7, 0, 5)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1505', 3.33333, 3, 1, 2, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1468', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1521', 5.83333, 12, 7, 0, 5)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1559', 7.76667, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1510', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3750', '2018-2#208#1415', 8.33333, 12, 10, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1375', 6.66667, 12, 8, 3, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1450', 1.66667, 12, 2, 1, 9)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1406', 5, 2, 1, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3752', '2018-2#208#1415', 3.33333, 12, 4, 1, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1551', 2.2, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1527', 0, 3, 0, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1480', 4.16667, 12, 5, 0, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1416', 7.5, 12, 9, 1, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1468', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1521', 9.16667, 12, 11, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1559', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1451', 1.66667, 12, 2, 0, 10)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1510', 3.33333, 12, 4, 0, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3743', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1551', 8.9, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1527', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1480', 9.725, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1505', 7.76667, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1468', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1521', 5, 12, 6, 0, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1450', 6.66667, 12, 8, 0, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1510', 8.60833, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3745', '2018-2#208#1415', 4.16667, 12, 5, 0, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3805', '2018-2#208#1375', 7.5, 12, 9, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3805', '2018-2#208#1406', 0, 2, 0, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3805', '2018-2#208#1371', 0, 2, 0, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3805', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3805', '2018-2#208#1325', 4.16667, 12, 5, 3, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3805', '2018-2#208#1415', 0, 12, 0, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1551', 0, 3, 0, 3, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1527', 0, 3, 0, 3, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1480', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1375', 8.33333, 12, 10, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1505', 1.1, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1416', 2.5, 12, 3, 0, 9)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1468', 0, 3, 0, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1521', 8.33333, 12, 10, 2, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1559', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1434', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1510', 3.33333, 12, 4, 1, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3746', '2018-2#208#1415', 5, 12, 6, 2, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1375', 7.5, 12, 9, 1, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1450', 2.5, 12, 3, 0, 9)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3748', '2018-2#208#1415', 5, 12, 6, 0, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1480', 1.66667, 12, 2, 0, 10)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1375', 6.66667, 12, 8, 0, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1468', 3.33333, 3, 1, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1450', 5.83333, 12, 7, 3, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1434', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1510', 4.16667, 12, 5, 1, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2049', '2018-2#208#1415', 4.16667, 12, 5, 1, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1551', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1527', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1480', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1505', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1416', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1468', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1521', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1451', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1510', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3751', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#1168', '2018-2#208#1324', 1.42857, 14, 2, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3744', '2018-2#208#1375', 0, 12, 0, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3744', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3744', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3744', '2018-2#208#1325', 9.16667, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3747', '2018-2#208#1375', 6.66667, 12, 8, 0, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3747', '2018-2#208#1450', 1.66667, 12, 2, 1, 9)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3747', '2018-2#208#1406', 0, 2, 0, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3747', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3747', '2018-2#208#1325', 8.33333, 12, 10, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3747', '2018-2#208#1415', 4.16667, 12, 5, 0, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1480', 1.66667, 12, 2, 0, 10)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1416', 2.5, 12, 3, 2, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1468', 0, 3, 0, 1, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2848', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1527', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1480', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1416', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1468', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1521', 1.66667, 12, 2, 0, 10)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1451', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1325', 5.83333, 12, 7, 0, 5)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3812', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1480', 7.5, 12, 9, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1505', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1468', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1521', 6.66667, 12, 8, 0, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1450', 6.66667, 12, 8, 3, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1559', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1510', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3620', '2018-2#208#1415', 5.83333, 12, 7, 1, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3030', '2018-2#208#1324', 9.28571, 14, 13, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1551', 5.56667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1527', 3.33333, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1480', 4.725, 12, 6, 1, 5)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1505', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1416', 4.16667, 12, 5, 0, 7)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1468', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1521', 5.83333, 12, 7, 0, 5)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1559', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1451', 0, 12, 0, 1, 11)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1510', 5, 12, 6, 0, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#3749', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1551', 8.9, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1527', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1480', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1375', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1505', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1416', 7.5, 12, 9, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1468', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1521', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1450', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1406', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1559', 3.33333, 3, 1, 0, 2)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1371', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1324', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1451', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1325', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1434', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1510', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2853', '2018-2#208#1415', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2864', '2018-2#208#1450', 0.833333, 12, 1, 0, 11)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#208#2891', '2018-2#208#1324', 1.42857, 14, 2, 2, 10)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1367', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1446', 10, 2, 2, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1412', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1460', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1327', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1526', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1472', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1345', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#206#2811', '2018-2#206#1411', 10, 12, 12, 0, 0)
# ...
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3711', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3711', '2018-2#205#1384', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1445', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1408', 5, 12, 6, 2, 4)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1404', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1323', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1530', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1357', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1470', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1525', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1456', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1497', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1546', 0, 3, 0, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1514', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1509', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3710', '2018-2#205#1384', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1445', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1408', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1404', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1323', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1357', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1470', 0, 3, 0, 0, 3)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1456', 1.66667, 12, 2, 2, 8)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1497', 0.833333, 12, 1, 0, 11)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3654', '2018-2#205#1384', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2916', '2018-2#205#1408', 0.833333, 12, 1, 0, 11)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2916', '2018-2#205#1323', 1.42857, 14, 2, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3780', '2018-2#205#1323', 3.57143, 14, 5, 3, 6)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3780', '2018-2#205#1335', 0, 12, 0, 0, 12)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1445', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1408', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1404', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1323', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1530', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1357', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1470', 3.33333, 3, 1, 1, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1525', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1456', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1497', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1546', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1514', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1509', 5.56667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3713', '2018-2#205#1384', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1445', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1408', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1404', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1323', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1530', 9.16667, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1357', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1470', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1525', 3.33333, 3, 1, 2, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1456', 9.16667, 12, 11, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1497', 9.725, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1548', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1546', 0, 3, 0, 3, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1514', 9.16667, 12, 11, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1509', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3704', '2018-2#205#1384', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1445', 7.5, 4, 3, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1408', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1404', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1323', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1530', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1357', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1470', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1525', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1456', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1497', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1548', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1546', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1514', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1509', 6.66667, 3, 2, 1, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#2197', '2018-2#205#1384', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1445', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1408', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1404', 0, 3, 0, 2, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1323', 10, 14, 14, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1530', 0, 12, 0, 1, 11)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1357', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1470', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1456', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1497', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1548', 6.66667, 3, 2, 0, 1)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1514', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1335', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3712', '2018-2#205#1509', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3782', '2018-2#205#1445', 10, 3, 3, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3782', '2018-2#205#1408', 10, 12, 12, 0, 0)
# INSERT INTO user_assessment (user_id, assessment_id, grade, number_exercises, correct, incorrect, blank) VALUES ('2018-2#205#3782', '2018-2#205#1404', 10, 3, 3, 0, 0)
